# %% [markdown]
# # Linear Algebra and Linear Regression
#
# ### by Neil Lawrence (2015)
#
#
# ## Sum of Squares Error
#
# Last week we considered a cost function for minimization of the error. We considered items (films) and users and assumed that each movie rating, $y_{i,j}$ could be summarised by an inner product between a vector associated with the item, $\mathbf{v}_j$ and one associated with the user $
# \mathbf{u}_i$. We justified the inner product as a measure of similarity in the space of 'movie subjects', where both the users and the items lived, giving the analogy of a library.
#
# To make predictions we encouraged the similarity to be high if the movie rating was high using the quadratic error function,
# $$
# E_{i,j}(\mathbf{u}_i, \mathbf{v}_j) = \left(\mathbf{u}_i^\top \mathbf{v}_j - y_{i,j}\right)^2,
# $$
# which we then summed across all the observations to form the total error
# $$
# E(\mathbf{U}, \mathbf{V}) = \sum_{i,j}s_{i,j}\left(\mathbf{u}_i^\top \mathbf{v}_j - y_{i,j}\right)^2,
# $$
# where $s_{i,j}$ is an indicator variable which is set to 1 if the rating of movie $j$ by user $i$ is provided in our data set.
#
# This is known as a sum of squares error. Minimizing it was first proposed by [Legendre](http://en.wikipedia.org/wiki/Adrien-Marie_Legendre) in 1805. His book, which was on the orbit of comets, is available on google books, we can take a look at the relevant page by calling the code below.

# %%
import pods
pods.notebook.display_google_book(id='spcAAAAAMAAJ', page=72)
# Out:
# <iframe frameborder="0" scrolling="yes" style="border:0px" src="http://books.google.co.uk/books?id=spcAAAAAMAAJ&pg=PA72&output=embed", width=700 height=500></iframe>

# %% [markdown]
# Of course, the main text is in French, but the key part we are interested in can be roughly translated as
#
# "In most matters where we take measures data through observation, the most accurate results they can offer, it is almost always leads to a system of equations of the form
# $$E = a + bx + cy + fz + etc .$$
# where a, b, c, f etc are the known coefficients and  x, y, z etc are unknown and must be determined by the condition that the value of E is reduced, for each equation, to an amount or zero or very small."
#
# He continues
#
# "Of all the principles that we can offer for this item, I think it is not broader, more accurate, nor easier than the one we have used in previous research application, and that is to make the minimum sum of the squares of the errors. By this means, it is between the errors a kind of balance that prevents extreme to prevail, is very specific to make known the state of the closest to the truth system. The sum of the squares of the errors $E^2 + \left.E^\prime\right.^2 + \left.E^{\prime\prime}\right.^2 + etc$ being
# \begin{align*}   &(a + bx + cy + fz + etc)^2 \\
# + &(a^\prime + b^\prime x + c^\prime y + f^\prime z + etc ) ^2\\
# + &(a^{\prime\prime} + b^{\prime\prime}x  + c^{\prime\prime}y +  f^{\prime\prime}z + etc )^2 \\
# + & etc
# \end{align*}
# if we wanted a minimum, by varying x alone, we will have the equation ..."
#
# This is the earliest known printed version of the problem of least squares. The notation, however, is a little awkward for mordern eyes. In particular Legendre doesn't make use of the sum sign,
# $$
# \sum_{i=1}^3 z_i = z_1 + z_2 + z_3
# $$
# nor does he make use of the inner product.
#
# In our notation, if we were to do linear regression, we would need to subsititue:
# \begin{align*}
# a &\leftarrow y_1-c, \\ a^\prime &\leftarrow y_2-c,\\ a^{\prime\prime} &\leftarrow y_3 -c,\\
# \text{etc.}
# \end{align*}
# to introduce the data observations $\{y_i\}_{i=1}^{n}$ alongside $c$, the offset. We would then introduce the input locations
# \begin{align*}
# b & \leftarrow x_1,\\
# b^\prime & \leftarrow x_2,\\
# b^{\prime\prime} & \leftarrow x_3\\
# \text{etc.}
# \end{align*}
# and finally the gradient of the function
# $$x \leftarrow -m.$$
# The remaining coefficients ($c$ and $f$) would then be zero. That would give us
# \begin{align*}   &(y_1 - (mx_1+c))^2 \\
# + &(y_2 -(mx_2 + c))^2\\
# + &(y_3 -(mx_3 + c))^2 \\
# + & \text{etc.}
# \end{align*}
# which we would write in the modern notation for sums as
# $$
# \sum_{i=1}^n (y_i-(mx_i + c))^2
# $$
# which is recognised as the sum of squares error for a linear regression.
#
# This shows the advantage of modern [summation operator](http://en.wikipedia.org/wiki/Summation), $\sum$,  in keeping our mathematical notation compact. Whilst it may look more complicated the first time you see it, understanding the mathematical rules that go around it, allows us to go much further with the notation.
#
# Inner products (or [dot products](http://en.wikipedia.org/wiki/Dot_product)) are similar. They allow us to write
# $$
# \sum_{i=1}^q u_i v_i
# $$
# in a more compact notation,
# $
# \mathbf{u}\cdot\mathbf{v}.
# $
#
# Here we are using bold face to represent vectors, and we assume that the individual elements of a vector $\mathbf{z}$ are given as a series of scalars
# $$
# \mathbf{z} = \begin{bmatrix} z_1\\ z_2\\ \vdots\\ z_n \end{bmatrix}
# $$
# which are each indexed by their position in the vector.
#
# ## Linear Algebra
#
# Linear algebra provides a very similar role, when we introduce [linear algebra](http://en.wikipedia.org/wiki/Linear_algebra), it is because we are faced with a large number of addition and multiplication operations. These operations need to be done together and would be very tedious to write down as a group. So the first reason we reach for linear algebra is for a more compact representation of our mathematical formulae.

# %% [markdown]
# ### Running Example: Olympic Marathons
#
# Now we will load in the Olympic marathon data. This is data of the olympic marathon times for the men's marathon from the first olympics in 1896 up until the London 2012 olympics.

# %%
data = pods.datasets.olympic_marathon_men()
x = data['X']
y = data['Y']

# %% [markdown]
# You can see what these values are by typing:

# %%
print(x)
print(y)
# Out:
# [[ 1896.]
#  [ 1900.]
#  [ 1904.]
#  [ 1908.]
#  [ 1912.]
#  [ 1920.]
#  [ 1924.]
#  [ 1928.]
#  [ 1932.]
#  [ 1936.]
#  [ 1948.]
#  [ 1952.]
#  [ 1956.]
#  [ 1960.]
#  [ 1964.]
#  [ 1968.]
#  [ 1972.]
#  [ 1976.]
#  [ 1980.]
#  [ 1984.]
#  [ 1988.]
#  [ 1992.]
#  [ 1996.]
#  [ 2000.]
#  [ 2004.]
#  [ 2008.]
#  [ 2012.]]
# [[ 4.47083333]
#  [ 4.46472926]
#  [ 5.22208333]
#  [ 4.15467867]
#  [ 3.90331675]
#  [ 3.56951267]
#  [ 3.82454477]
#  [ 3.62483707]
#  [ 3.59284275]
#  [ 3.53880792]
#  [ 3.67010309]
#  [ 3.39029111]
#  [ 3.43642612]
#  [ 3.20583007]
#  [ 3.13275665]
#  [ 3.32819844]
#  [ 3.13583758]
#  [ 3.0789588 ]
#  [ 3.10581822]
#  [ 3.06552909]
#  [ 3.09357349]
#  [ 3.16111704]
#  [ 3.14255244]
#  [ 3.08527867]
#  [ 3.10265829]
#  [ 2.99877553]
#  [ 3.03392977]]

# %% [markdown]
# Note that they are not `pandas` data frames for this example, they are just arrays of dimensionality $n\times 1$, where $n$ is the number of data.

# %% [markdown]
# The aim of this lab is to have you coding linear regression in python. We will do it in two ways, once using iterative updates (coordinate ascent) and then using linear algebra. The linear algebra approach will not only work much better, it is easy to extend to multiple input linear regression and *non-linear* regression using basis functions.

# %% [markdown]
# ### Plotting the Data
#
# You can make a plot of $y$ vs $x$ with the following command:

# %%
# %matplotlib inline 
import pylab as plt

plt.plot(x, y, 'rx')
plt.xlabel('year')
plt.ylabel('pace in min/km')

# %% [markdown]
# ### Maximum Likelihood: Iterative Solution

# %% [markdown]
# Now we will take the maximum likelihood approach we derived in the lecture to fit a line, $y_i=mx_i + c$, to the data you've plotted. We are trying to minimize the error function:

# %% [markdown]
# $$E(m, c) =  \sum_{i=1}^n(y_i-mx_i-c)^2$$

# %% [markdown]
# with respect to $m$, $c$ and $\sigma^2$. We can start with an initial guess for $m$,

# %%
m = -0.4
c = 80

# %% [markdown]
# Then we use the maximum likelihood update to find an estimate for the offset, $c$.
#
# ### Coordinate Descent
#
# In the movie recommender system example, we minimised the objective function by steepest descent based gradient methods. Our updates required us to compute the gradient at the position we were located, then to update the gradient according to the direction of steepest descent. This time, we will take another approach. It is known as *coordinate descent*. In coordinate descent, we choose to move one parameter at a time. Ideally, we design an algorithm that at each step moves the parameter to its minimum value. At each step we choose to move the individual parameter to its minimum.
#
# To find the minimum, we look for the point in the curve where the gradient is zero. This can be found by taking the gradient of $E(m,c)$ with respect to the parameter.
#
# #### Update for Offset
#
# Let's consider the parameter $c$ first. The gradient goes nicely through the summation operator, and we obtain
# $$
# \frac{\text{d}E(m,c)}{\text{d}c} = -\sum_{i=1}^n 2(y_i-mx_i-c).
# $$
# Now we want the point that is a minimum. A minimum is an example of a [*stationary point*](http://en.wikipedia.org/wiki/Stationary_point), the stationary points are those points of the function where the gradient is zero. They are found by solving the equation for $\frac{\text{d}E(m,c)}{\text{d}c} = 0$. Substituting in to our gradient, we can obtain the following equation,
# $$
# 0 = -\sum_{i=1}^n 2(y_i-mx_i-c)
# $$
# which can be reorganised as follows,
# $$
# c^* = \frac{\sum_{i=1}^n(y_i-m^*x_i)}{n}.
# $$
# The fact that the stationary point is easily extracted in this manner implies that the solution is *unique*. There is only one stationary point for this system. Traditionally when trying to determine the type of stationary point we have encountered we now compute the *second derivative*,
# $$
# \frac{\text{d}^2E(m,c)}{\text{d}c^2} = 2n.
# $$
# The second derivative is positive, which in turn implies that we have found a minimum of the function. This means that setting $c$ in this way will take us to the lowest point along that axes.

# %%
# set c to the minimum
c = (y - m*x).mean()
print(c)
# Out:
# 786.019771145

# %% [markdown]
# #### Update for Slope
#
# Now we have the offset set to the minimum value, in coordinate descent, the next step is to optimise another parameter. Only one further parameter remains. That is the slope of the system.
#
# Now we can turn our attention to the slope. We once again peform the same set of computations to find the minima. We end up with an update equation of the following form.
#
# $$m^* = \frac{\sum_{i=1}^n (y_i - c)x_i}{\sum_{i=1}^n x_i^2}$$
#
# Communication of mathematics in data science is an essential skill, in a moment, you will be asked to rederive the equation above. Before we do that, however, we will briefly review how to write mathematics in the notebook.
#
# ### $\LaTeX$ for Maths
#
# These cells use [Markdown format](http://en.wikipedia.org/wiki/Markdown). You can include maths in your markdown using [$\LaTeX$ syntax](http://en.wikipedia.org/wiki/LaTeX), all you have to do is write your answer inside dollar signs, as follows:
#
# To write a fraction, we write `$\frac{a}{b}$`, and it will display like this $\frac{a}{b}$. To write a subscript we write `$a_b$` which will appear as $a_b$. To write a superscript (for example in a polynomial) we write `$a^b$` which will appear as $a^b$. There are lots of other macros as well, for example we can do greek letters such as `$\alpha, \beta, \gamma$` rendering as $\alpha, \beta, \gamma$. And we can do sum and intergral signs as `$\sum \int \int$`.
#
# You can combine many of these operations together for composing expressions.

# %% [markdown]
# ### Assignment Question 1
#
# Convert the following python code expressions into $\LaTeX$j, writing your answers below. In each case write your answer as a single equality (i.e. your maths should only contain one expression, not several lines of expressions). For the purposes of your $\LaTeX$ please assume that `x` and `w` are $n$ dimensional vectors.
#
# (a)
# ``` python
# f = x.sum()
# ```
#
# (b)
# ``` python
# m = x.mean()
# ```
#
# (c)
# ``` python
# g = (x*w).sum()
# ```
#
# *7.5 marks*

# %% [markdown]
# #### Question 1 Answer
#
# Write your answer to the question in this box.
#
# a)   $f = {\sum_{i=1}^n x_i}$
#
# b) $m = {\frac{\sum_{i=1}^n x_i} {n}}$
#
# c) $g = {\sum_{i=1}^n x_i w_i}$

# %% [markdown]
# ### Gradient With Respect to the Slope
# Now that you've had a little training in writing maths with $\LaTeX$, we will be able to use it to answer questions. The next thing we are going to do is a little differentiation practice.

# %% [markdown]
# ### Assignment Question 2
#
# Derive the the gradient of the objective function with respect to the slope, $m$. Rearrange it to show that the update equation written above does find the stationary points of the objective function. By computing its derivative show that it's a minimum.
#
# *10 marks*

# %% [markdown]
# #### Question 2 Answer
#
# Write your answer to the question in this box.
#
#
# $$E(m, c) =  \sum_{i=1}^n(y_i-mx_i-c)^2$$
#
#
# $$
# \frac{\text{d}E(m,c)}{\text{d}m} = -\sum_{i=1}^n 2x_i(y_i-mx_i-c).
# $$
#
# Set derivative equal to zero to find stationary points. This is because stationary points are those points of the function where the gradient is zero:
#
# $$
# \frac{\text{d}E(m,c)}{\text{d}m} = 0
# $$
#
# Therefore:
# $$
# 0 = -\sum_{i=1}^n 2x_i(y_i-mx_i-c).
# $$
#
# Which is equal to:
#
# $$
# 0 = -\sum_{i=1}^n 2x_i(y_i-c) + \sum_{i=1}^n 2x_i(mx_i)
# $$
#
#
#
#
#
# $$
# \sum_{i=1}^n 2x_i(mx_i) = \sum_{i=1}^n 2x_i(y_i-c)
# $$
#
#
# Therefore:
#
# $$
# m^* = \frac{\sum_{i=1}^n (y_i - c)x_i}{\sum_{i=1}^n x_i^2}
# $$
#
#
#
# In order to show that it is a minimum, the second derivative is required.
# If the second derivative is positive, then it is a minimum.
#
# $$
# \frac{\text{d}^2E(m,c)}{\text{d}m^2} = \sum_{i=1}^n 2x_i^2.
# $$
#
# Second derivative is positive, therefore it's a minimum.

# %%
m = ((y - c)*x).sum()/(x**2).sum()
print(m)
# Out:
# -0.3998724073

# %% [markdown]
# We can have a look at how good our fit is by computing the prediction across the input space. First create a vector of 'test points',

# %%
import numpy as np
x_test = np.linspace(1890, 2020, 130)[:, None]

# %% [markdown]
# Now use this vector to compute some test predictions,

# %%
f_test = m*x_test + c

# %% [markdown]
# Now plot those test predictions with a blue line on the same plot as the data,

# %%
plt.plot(x_test, f_test, 'b-')
plt.plot(x, y, 'rx')

# %% [markdown]
# The fit isn't very good, we need to iterate between these parameter updates in a loop to improve the fit, we have to do this several times,

# %%
for i in np.arange(10):
    m = ((y - c)*x).sum()/(x*x).sum()
    c = (y-m*x).sum()/y.shape[0]
print(m)
print(c)
# Out:
# -0.398725964251
# 783.527379727

# %% [markdown]
# And let's try plotting the result again

# %%
f_test = m*x_test + c
plt.plot(x_test, f_test, 'b-')
plt.plot(x, y, 'rx')

# %% [markdown]
# Clearly we need more iterations than 10! In the next question you will add more iterations and report on the error as optimisation proceeds.

# %% [markdown]
# ### Assignment Question 3
#
# There is a problem here, we seem to need many interations to get to a good solution. Let's explore what's going on. Write code which alternates between updates of `c` and `m`. Include the following features in your code.
#
# (a) Initialise with `m=-0.4` and `c=80`.
# (b) Every 10 iterations compute the value of the objective function for the training data and print it to the screen (you'll find hints on this in the lab from last week.
# (c) Cause the code to stop running when the error change over less than 10 iterations is smaller than $1\times10^{-4}$. This is known as a stopping criterion.
#
# Why do we need so many iterations to get to the solution?
#
# *12.5 marks*

# %%
# Question 3 Answer Code
# Write code for you answer to this question in this box
# Do not delete these comments, otherwise you will get zero for this answer.
# Make sure your code has run and the answer is correct *before* submitting your notebook for marking.


import numpy as np


data = pods.datasets.olympic_marathon_men()
x = data['X']
y = data['Y']


m = -0.4
c = 80 

obj = ((y-m*x-c)**2).sum()
var = 0
counter = 0
iterations = 50000

for i in np.arange(iterations):
    m = ((y - c)*x).sum()/(x*x).sum()
    c = (y-m*x).sum()/y.shape[0]
            
    if not counter % 10: 
        print ("Update:", counter, "Objective:", obj) 
        var = obj
        obj = ((y-m*x-c)**2).sum()
    
        if ((var - obj) < 0.0001):
            break
    counter += 1
    
print("m: ", m, "c:", c)

f_test = m*x_test + c
plt.plot(x_test, f_test, 'b-')
plt.plot(x, y, 'rx')
# Out:
# Update: 0 Objective: 13463632.0286
# Update: 10 Objective: 25.2199941523
# Update: 20 Objective: 25.0672376076
# Update: 30 Objective: 24.9154851313
# Update: 40 Objective: 24.7647301237
# Update: 50 Objective: 24.6149660285
# Update: 60 Objective: 24.4661863325
# Update: 70 Objective: 24.3183845651
# Update: 80 Objective: 24.1715542985
# Update: 90 Objective: 24.0256891469
# Update: 100 Objective: 23.8807827667
# Update: 110 Objective: 23.7368288558
# Update: 120 Objective: 23.5938211538
# Update: 130 Objective: 23.4517534411
# Update: 140 Objective: 23.3106195392
# Update: 150 Objective: 23.1704133101
# Update: 160 Objective: 23.0311286564
# Update: 170 Objective: 22.8927595204
# Update: 180 Objective: 22.7552998845
# Update: 190 Objective: 22.6187437706
# Update: 200 Objective: 22.4830852397
# Update: 210 Objective: 22.3483183921
# Update: 220 Objective: 22.2144373667
# Update: 230 Objective: 22.081436341
# Update: 240 Objective: 21.9493095309
# Update: 250 Objective: 21.81805119
# Update: 260 Objective: 21.68765561
# Update: 270 Objective: 21.5581171198
# Update: 280 Objective: 21.4294300859
# Update: 290 Objective: 21.3015889117
# Update: 300 Objective: 21.1745880372
# Update: 310 Objective: 21.0484219392
# Update: 320 Objective: 20.9230851308
# Update: 330 Objective: 20.798572161
# Update: 340 Objective: 20.6748776147
# Update: 350 Objective: 20.5519961124
# Update: 360 Objective: 20.42992231
# Update: 370 Objective: 20.3086508985
# Update: 380 Objective: 20.1881766037
# Update: 390 Objective: 20.0684941863
# Update: 400 Objective: 19.9495984412
# Update: 410 Objective: 19.8314841975
# Update: 420 Objective: 19.7141463186
# Update: 430 Objective: 19.5975797013
# Update: 440 Objective: 19.4817792762
# Update: 450 Objective: 19.3667400071
# Update: 460 Objective: 19.2524568909
# Update: 470 Objective: 19.1389249574
# Update: 480 Objective: 19.026139269
# Update: 490 Objective: 18.9140949208
# Update: 500 Objective: 18.8027870399
# Update: 510 Objective: 18.6922107854
# Update: 520 Objective: 18.5823613485
# Update: 530 Objective: 18.4732339517
# Update: 540 Objective: 18.3648238491
# Update: 550 Objective: 18.2571263259
# Update: 560 Objective: 18.1501366984
# Update: 570 Objective: 18.0438503134
# Update: 580 Objective: 17.9382625487
# Update: 590 Objective: 17.8333688121
# Update: 600 Objective: 17.7291645419
# Update: 610 Objective: 17.6256452061
# Update: 620 Objective: 17.5228063027
# Update: 630 Objective: 17.4206433593
# Update: 640 Objective: 17.3191519327
# Update: 650 Objective: 17.218327609
# Update: 660 Objective: 17.1181660035
# Update: 670 Objective: 17.01866276
# Update: 680 Objective: 16.9198135511
# Update: 690 Objective: 16.8216140779
# Update: 700 Objective: 16.7240600696
# Update: 710 Objective: 16.6271472837
# Update: 720 Objective: 16.5308715053
# Update: 730 Objective: 16.4352285474
# Update: 740 Objective: 16.3402142505
# Update: 750 Objective: 16.2458244824
# Update: 760 Objective: 16.1520551381
# Update: 770 Objective: 16.0589021395
# Update: 780 Objective: 15.9663614354
# Update: 790 Objective: 15.8744290012
# Update: 800 Objective: 15.7831008386
# Update: 810 Objective: 15.692372976
# Update: 820 Objective: 15.6022414673
# Update: 830 Objective: 15.512702393
# Update: 840 Objective: 15.4237518588
# Update: 850 Objective: 15.3353859963
# Update: 860 Objective: 15.2476009624
# Update: 870 Objective: 15.1603929394
# Update: 880 Objective: 15.0737581346
# Update: 890 Objective: 14.9876927802
# Update: 900 Objective: 14.9021931332
# Update: 910 Objective: 14.8172554752
# Update: 920 Objective: 14.7328761123
# Update: 930 Objective: 14.6490513748
# Update: 940 Objective: 14.5657776171
# Update: 950 Objective: 14.4830512177
# Update: 960 Objective: 14.4008685787
# Update: 970 Objective: 14.3192261261
# Update: 980 Objective: 14.2381203092
# Update: 990 Objective: 14.1575476006
# Update: 1000 Objective: 14.0775044963
# Update: 1010 Objective: 13.9979875152
# Update: 1020 Objective: 13.9189931991
# Update: 1030 Objective: 13.8405181124
# Update: 1040 Objective: 13.7625588424
# Update: 1050 Objective: 13.6851119984
# Update: 1060 Objective: 13.6081742125
# Update: 1070 Objective: 13.5317421385
# Update: 1080 Objective: 13.4558124523
# Update: 1090 Objective: 13.3803818518
# Update: 1100 Objective: 13.3054470566
# Update: 1110 Objective: 13.2310048075
# Update: 1120 Objective: 13.1570518673
# Update: 1130 Objective: 13.0835850196
# Update: 1140 Objective: 13.0106010694
# Update: 1150 Objective: 12.9380968425
# Update: 1160 Objective: 12.8660691857
# Update: 1170 Objective: 12.7945149667
# Update: 1180 Objective: 12.7234310733
# Update: 1190 Objective: 12.6528144143
# Update: 1200 Objective: 12.5826619184
# Update: 1210 Objective: 12.5129705348
# Update: 1220 Objective: 12.4437372325
# Update: 1230 Objective: 12.3749590005
# Update: 1240 Objective: 12.3066328478
# Update: 1250 Objective: 12.2387558027
# Update: 1260 Objective: 12.1713249133
# Update: 1270 Objective: 12.104337247
# Update: 1280 Objective: 12.0377898905
# Update: 1290 Objective: 11.9716799497
# Update: 1300 Objective: 11.9060045494
# Update: 1310 Objective: 11.8407608334
# Update: 1320 Objective: 11.7759459642
# Update: 1330 Objective: 11.711557123
# Update: 1340 Objective: 11.6475915096
# Update: 1350 Objective: 11.584046342
# Update: 1360 Objective: 11.5209188566
# Update: 1370 Objective: 11.4582063081
# Update: 1380 Objective: 11.3959059691
# Update: 1390 Objective: 11.3340151301
# Update: 1400 Objective: 11.2725310995
# Update: 1410 Objective: 11.2114512033
# Update: 1420 Objective: 11.1507727851
# Update: 1430 Objective: 11.090493206
# Update: 1440 Objective: 11.0306098445
# Update: 1450 Objective: 10.9711200963
# Update: 1460 Objective: 10.912021374
# Update: 1470 Objective: 10.8533111075
# Update: 1480 Objective: 10.7949867435
# Update: 1490 Objective: 10.7370457455
# Update: 1500 Objective: 10.6794855935
# Update: 1510 Objective: 10.6223037843
# Update: 1520 Objective: 10.565497831
# Update: 1530 Objective: 10.5090652631
# Update: 1540 Objective: 10.4530036264
# Update: 1550 Objective: 10.3973104827
# Update: 1560 Objective: 10.34198341
# Update: 1570 Objective: 10.287020002
# Update: 1580 Objective: 10.2324178684
# Update: 1590 Objective: 10.1781746345
# Update: 1600 Objective: 10.1242879412
# Update: 1610 Objective: 10.0707554451
# Update: 1620 Objective: 10.017574818
# Update: 1630 Objective: 9.96474374711
# Update: 1640 Objective: 9.91225993471
# Update: 1650 Objective: 9.86012109831
# Update: 1660 Objective: 9.80832497039
# Update: 1670 Objective: 9.75686929831
# Update: 1680 Objective: 9.70575184427
# Update: 1690 Objective: 9.65497038517
# Update: 1700 Objective: 9.60452271249
# Update: 1710 Objective: 9.55440663228
# Update: 1720 Objective: 9.50461996497
# Update: 1730 Objective: 9.45516054533
# Update: 1740 Objective: 9.40602622236
# Update: 1750 Objective: 9.3572148592
# Update: 1760 Objective: 9.30872433304
# Update: 1770 Objective: 9.26055253503
# Update: 1780 Objective: 9.21269737014
# Update: 1790 Objective: 9.16515675717
# Update: 1800 Objective: 9.11792862856
# Update: 1810 Objective: 9.07101093035
# Update: 1820 Objective: 9.02440162208
# Update: 1830 Objective: 8.97809867671
# Update: 1840 Objective: 8.93210008051
# Update: 1850 Objective: 8.886403833
# Update: 1860 Objective: 8.84100794684
# Update: 1870 Objective: 8.79591044775
# Update: 1880 Objective: 8.75110937444
# Update: 1890 Objective: 8.7066027785
# Update: 1900 Objective: 8.66238872433
# Update: 1910 Objective: 8.61846528906
# Update: 1920 Objective: 8.57483056245
# Update: 1930 Objective: 8.53148264681
# Update: 1940 Objective: 8.48841965694
# Update: 1950 Objective: 8.44563972002
# Update: 1960 Objective: 8.40314097555
# Update: 1970 Objective: 8.36092157524
# Update: 1980 Objective: 8.31897968298
# Update: 1990 Objective: 8.27731347469
# Update: 2000 Objective: 8.23592113832
# Update: 2010 Objective: 8.19480087369
# Update: 2020 Objective: 8.15395089248
# Update: 2030 Objective: 8.11336941813
# Update: 2040 Objective: 8.07305468573
# Update: 2050 Objective: 8.03300494199
# Update: 2060 Objective: 7.99321844514
# Update: 2070 Objective: 7.95369346486
# Update: 2080 Objective: 7.91442828221
# Update: 2090 Objective: 7.87542118952
# Update: 2100 Objective: 7.83667049038
# Update: 2110 Objective: 7.79817449952
# Update: 2120 Objective: 7.75993154273
# Update: 2130 Objective: 7.72193995682
# Update: 2140 Objective: 7.68419808954
# Update: 2150 Objective: 7.64670429948
# Update: 2160 Objective: 7.60945695603
# Update: 2170 Objective: 7.57245443931
# Update: 2180 Objective: 7.53569514005
# Update: 2190 Objective: 7.4991774596
# Update: 2200 Objective: 7.46289980979
# Update: 2210 Objective: 7.42686061291
# Update: 2220 Objective: 7.39105830161
# Update: 2230 Objective: 7.35549131882
# Update: 2240 Objective: 7.32015811775
# Update: 2250 Objective: 7.28505716175
# Update: 2260 Objective: 7.25018692426
# Update: 2270 Objective: 7.21554588878
# Update: 2280 Objective: 7.18113254876
# Update: 2290 Objective: 7.14694540756
# Update: 2300 Objective: 7.11298297837
# Update: 2310 Objective: 7.07924378417
# Update: 2320 Objective: 7.04572635763
# Update: 2330 Objective: 7.01242924107
# Update: 2340 Objective: 6.97935098639
# Update: 2350 Objective: 6.94649015502
# Update: 2360 Objective: 6.91384531784
# Update: 2370 Objective: 6.88141505511
# Update: 2380 Objective: 6.84919795643
# Update: 2390 Objective: 6.81719262068
# Update: 2400 Objective: 6.78539765595
# Update: 2410 Objective: 6.75381167946
# Update: 2420 Objective: 6.72243331753
# Update: 2430 Objective: 6.69126120552
# Update: 2440 Objective: 6.66029398774
# Update: 2450 Objective: 6.62953031743
# Update: 2460 Objective: 6.59896885666
# Update: 2470 Objective: 6.56860827632
# Update: 2480 Objective: 6.53844725602
# Update: 2490 Objective: 6.50848448404
# Update: 2500 Objective: 6.47871865731
# Update: 2510 Objective: 6.44914848131
# Update: 2520 Objective: 6.41977267001
# Update: 2530 Objective: 6.39058994587
# Update: 2540 Objective: 6.36159903972
# Update: 2550 Objective: 6.33279869074
# Update: 2560 Objective: 6.3041876464
# Update: 2570 Objective: 6.2757646624
# Update: 2580 Objective: 6.24752850262
# Update: 2590 Objective: 6.21947793907
# Update: 2600 Objective: 6.19161175182
# Update: 2610 Objective: 6.16392872897
# Update: 2620 Objective: 6.13642766657
# Update: 2630 Objective: 6.10910736861
# Update: 2640 Objective: 6.08196664691
# Update: 2650 Objective: 6.05500432113
# Update: 2660 Objective: 6.02821921866
# Update: 2670 Objective: 6.00161017462
# Update: 2680 Objective: 5.97517603178
# Update: 2690 Objective: 5.94891564051
# Update: 2700 Objective: 5.92282785874
# Update: 2710 Objective: 5.89691155191
# Update: 2720 Objective: 5.87116559292
# Update: 2730 Objective: 5.84558886207
# Update: 2740 Objective: 5.82018024703
# Update: 2750 Objective: 5.79493864276
# Update: 2760 Objective: 5.76986295151
# Update: 2770 Objective: 5.74495208273
# Update: 2780 Objective: 5.72020495305
# Update: 2790 Objective: 5.6956204862
# Update: 2800 Objective: 5.67119761301
# Update: 2810 Objective: 5.64693527131
# Update: 2820 Objective: 5.62283240595
# Update: 2830 Objective: 5.59888796867
# Update: 2840 Objective: 5.57510091814
# Update: 2850 Objective: 5.55147021984
# Update: 2860 Objective: 5.52799484608
# Update: 2870 Objective: 5.5046737759
# Update: 2880 Objective: 5.48150599508
# Update: 2890 Objective: 5.45849049604
# Update: 2900 Objective: 5.43562627783
# Update: 2910 Objective: 5.41291234608
# Update: 2920 Objective: 5.39034771296
# Update: 2930 Objective: 5.36793139714
# Update: 2940 Objective: 5.34566242372
# Update: 2950 Objective: 5.32353982421
# Update: 2960 Objective: 5.30156263652
# Update: 2970 Objective: 5.27972990483
# Update: 2980 Objective: 5.25804067965
# Update: 2990 Objective: 5.23649401771
# Update: 3000 Objective: 5.21508898194
# Update: 3010 Objective: 5.19382464142
# Update: 3020 Objective: 5.17270007138
# Update: 3030 Objective: 5.1517143531
# Update: 3040 Objective: 5.1308665739
# Update: 3050 Objective: 5.11015582712
# Update: 3060 Objective: 5.08958121203
# Update: 3070 Objective: 5.06914183386
# Update: 3080 Objective: 5.04883680367
# Update: 3090 Objective: 5.02866523842
# Update: 3100 Objective: 5.00862626082
# Update: 3110 Objective: 4.98871899939
# Update: 3120 Objective: 4.96894258834
# Update: 3130 Objective: 4.94929616761
# Update: 3140 Objective: 4.92977888277
# Update: 3150 Objective: 4.91038988501
# Update: 3160 Objective: 4.89112833109
# Update: 3170 Objective: 4.87199338333
# Update: 3180 Objective: 4.85298420954
# Update: 3190 Objective: 4.83409998302
# Update: 3200 Objective: 4.81533988248
# Update: 3210 Objective: 4.79670309205
# Update: 3220 Objective: 4.77818880121
# Update: 3230 Objective: 4.75979620476
# Update: 3240 Objective: 4.74152450282
# Update: 3250 Objective: 4.72337290075
# Update: 3260 Objective: 4.70534060911
# Update: 3270 Objective: 4.6874268437
# Update: 3280 Objective: 4.66963082543
# Update: 3290 Objective: 4.65195178036
# Update: 3300 Objective: 4.63438893962
# Update: 3310 Objective: 4.6169415394
# Update: 3320 Objective: 4.59960882091
# Update: 3330 Objective: 4.58239003034
# Update: 3340 Objective: 4.56528441885
# Update: 3350 Objective: 4.54829124252
# Update: 3360 Objective: 4.5314097623
# Update: 3370 Objective: 4.51463924401
# Update: 3380 Objective: 4.49797895832
# Update: 3390 Objective: 4.48142818065
# Update: 3400 Objective: 4.46498619121
# Update: 3410 Objective: 4.44865227494
# Update: 3420 Objective: 4.43242572146
# Update: 3430 Objective: 4.4163058251
# Update: 3440 Objective: 4.40029188478
# Update: 3450 Objective: 4.38438320406
# Update: 3460 Objective: 4.36857909107
# Update: 3470 Objective: 4.35287885849
# Update: 3480 Objective: 4.3372818235
# Update: 3490 Objective: 4.3217873078
# Update: 3500 Objective: 4.30639463752
# Update: 3510 Objective: 4.29110314323
# Update: 3520 Objective: 4.27591215991
# Update: 3530 Objective: 4.26082102689
# Update: 3540 Objective: 4.24582908786
# Update: 3550 Objective: 4.23093569081
# Update: 3560 Objective: 4.21614018804
# Update: 3570 Objective: 4.20144193608
# Update: 3580 Objective: 4.1868402957
# Update: 3590 Objective: 4.17233463188
# Update: 3600 Objective: 4.15792431376
# Update: 3610 Objective: 4.14360871463
# Update: 3620 Objective: 4.12938721191
# Update: 3630 Objective: 4.1152591871
# Update: 3640 Objective: 4.10122402577
# Update: 3650 Objective: 4.08728111753
# Update: 3660 Objective: 4.073429856
# Update: 3670 Objective: 4.05966963879
# Update: 3680 Objective: 4.04599986745
# Update: 3690 Objective: 4.0324199475
# Update: 3700 Objective: 4.01892928834
# Update: 3710 Objective: 4.00552730325
# Update: 3720 Objective: 3.99221340939
# Update: 3730 Objective: 3.97898702773
# Update: 3740 Objective: 3.96584758305
# Update: 3750 Objective: 3.95279450391
# Update: 3760 Objective: 3.93982722264
# Update: 3770 Objective: 3.92694517529
# Update: 3780 Objective: 3.9141478016
# Update: 3790 Objective: 3.90143454504
# Update: 3800 Objective: 3.88880485268
# Update: 3810 Objective: 3.87625817526
# Update: 3820 Objective: 3.86379396714
# Update: 3830 Objective: 3.85141168623
# Update: 3840 Objective: 3.83911079403
# Update: 3850 Objective: 3.82689075557
# Update: 3860 Objective: 3.8147510394
# Update: 3870 Objective: 3.80269111757
# Update: 3880 Objective: 3.79071046557
# Update: 3890 Objective: 3.77880856238
# Update: 3900 Objective: 3.76698489038
# Update: 3910 Objective: 3.75523893535
# Update: 3920 Objective: 3.74357018646
# Update: 3930 Objective: 3.73197813624
# Update: 3940 Objective: 3.72046228054
# Update: 3950 Objective: 3.70902211854
# Update: 3960 Objective: 3.6976571527
# Update: 3970 Objective: 3.68636688876
# Update: 3980 Objective: 3.67515083571
# Update: 3990 Objective: 3.66400850575
# Update: 4000 Objective: 3.6529394143
# Update: 4010 Objective: 3.64194307998
# Update: 4020 Objective: 3.63101902453
# Update: 4030 Objective: 3.62016677289
# Update: 4040 Objective: 3.60938585307
# Update: 4050 Objective: 3.59867579622
# Update: 4060 Objective: 3.58803613655
# Update: 4070 Objective: 3.57746641135
# Update: 4080 Objective: 3.56696616093
# Update: 4090 Objective: 3.55653492863
# Update: 4100 Objective: 3.54617226081
# Update: 4110 Objective: 3.53587770678
# Update: 4120 Objective: 3.52565081884
# Update: 4130 Objective: 3.51549115221
# Update: 4140 Objective: 3.50539826505
# Update: 4150 Objective: 3.49537171842
# Update: 4160 Objective: 3.48541107626
# Update: 4170 Objective: 3.47551590539
# Update: 4180 Objective: 3.46568577545
# Update: 4190 Objective: 3.45592025894
# Update: 4200 Objective: 3.44621893115
# Update: 4210 Objective: 3.43658137018
# Update: 4220 Objective: 3.42700715687
# Update: 4230 Objective: 3.41749587485
# Update: 4240 Objective: 3.40804711046
# Update: 4250 Objective: 3.39866045279
# Update: 4260 Objective: 3.3893354936
# Update: 4270 Objective: 3.38007182735
# Update: 4280 Objective: 3.37086905116
# Update: 4290 Objective: 3.3617267648
# Update: 4300 Objective: 3.35264457068
# Update: 4310 Objective: 3.34362207379
# Update: 4320 Objective: 3.33465888177
# Update: 4330 Objective: 3.32575460478
# Update: 4340 Objective: 3.3169088556
# Update: 4350 Objective: 3.3081212495
# Update: 4360 Objective: 3.29939140433
# Update: 4370 Objective: 3.29071894041
# Update: 4380 Objective: 3.28210348058
# Update: 4390 Objective: 3.27354465015
# Update: 4400 Objective: 3.2650420769
# Update: 4410 Objective: 3.25659539104
# Update: 4420 Objective: 3.24820422524
# Update: 4430 Objective: 3.23986821455
# Update: 4440 Objective: 3.23158699644
# Update: 4450 Objective: 3.22336021077
# Update: 4460 Objective: 3.21518749974
# Update: 4470 Objective: 3.20706850793
# Update: 4480 Objective: 3.19900288224
# Update: 4490 Objective: 3.19099027189
# Update: 4500 Objective: 3.18303032841
# Update: 4510 Objective: 3.17512270562
# Update: 4520 Objective: 3.16726705963
# Update: 4530 Objective: 3.15946304878
# Update: 4540 Objective: 3.15171033368
# Update: 4550 Objective: 3.14400857716
# Update: 4560 Objective: 3.13635744427
# Update: 4570 Objective: 3.12875660227
# Update: 4580 Objective: 3.12120572058
# Update: 4590 Objective: 3.11370447083
# Update: 4600 Objective: 3.10625252678
# Update: 4610 Objective: 3.09884956434
# Update: 4620 Objective: 3.09149526156
# Update: 4630 Objective: 3.0841892986
# Update: 4640 Objective: 3.07693135771
# Update: 4650 Objective: 3.06972112327
# Update: 4660 Objective: 3.06255828167
# Update: 4670 Objective: 3.05544252143
# Update: 4680 Objective: 3.04837353306
# Update: 4690 Objective: 3.04135100914
# Update: 4700 Objective: 3.03437464425
# Update: 4710 Objective: 3.027444135
# Update: 4720 Objective: 3.02055917997
# Update: 4730 Objective: 3.01371947974
# Update: 4740 Objective: 3.00692473685
# Update: 4750 Objective: 3.00017465579
# Update: 4760 Objective: 2.993468943
# Update: 4770 Objective: 2.98680730684
# Update: 4780 Objective: 2.98018945761
# Update: 4790 Objective: 2.97361510749
# Update: 4800 Objective: 2.96708397056
# Update: 4810 Objective: 2.96059576278
# Update: 4820 Objective: 2.95415020198
# Update: 4830 Objective: 2.94774700784
# Update: 4840 Objective: 2.94138590188
# Update: 4850 Objective: 2.93506660746
# Update: 4860 Objective: 2.92878884975
# Update: 4870 Objective: 2.92255235573
# Update: 4880 Objective: 2.91635685417
# Update: 4890 Objective: 2.91020207563
# Update: 4900 Objective: 2.90408775244
# Update: 4910 Objective: 2.89801361868
# Update: 4920 Objective: 2.8919794102
# Update: 4930 Objective: 2.88598486456
# Update: 4940 Objective: 2.88002972105
# Update: 4950 Objective: 2.87411372069
# Update: 4960 Objective: 2.86823660619
# Update: 4970 Objective: 2.86239812195
# Update: 4980 Objective: 2.85659801406
# Update: 4990 Objective: 2.85083603027
# Update: 5000 Objective: 2.84511191998
# Update: 5010 Objective: 2.83942543426
# Update: 5020 Objective: 2.8337763258
# Update: 5030 Objective: 2.82816434892
# Update: 5040 Objective: 2.82258925956
# Update: 5050 Objective: 2.81705081524
# Update: 5060 Objective: 2.81154877511
# Update: 5070 Objective: 2.80608289988
# Update: 5080 Objective: 2.80065295184
# Update: 5090 Objective: 2.79525869484
# Update: 5100 Objective: 2.78989989427
# Update: 5110 Objective: 2.7845763171
# Update: 5120 Objective: 2.77928773178
# Update: 5130 Objective: 2.77403390833
# Update: 5140 Objective: 2.76881461825
# Update: 5150 Objective: 2.76362963455
# Update: 5160 Objective: 2.75847873174
# Update: 5170 Objective: 2.75336168581
# Update: 5180 Objective: 2.74827827421
# Update: 5190 Objective: 2.74322827586
# Update: 5200 Objective: 2.73821147115
# Update: 5210 Objective: 2.73322764188
# Update: 5220 Objective: 2.72827657131
# Update: 5230 Objective: 2.72335804412
# Update: 5240 Objective: 2.7184718464
# Update: 5250 Objective: 2.71361776565
# Update: 5260 Objective: 2.70879559076
# Update: 5270 Objective: 2.70400511202
# Update: 5280 Objective: 2.69924612108
# Update: 5290 Objective: 2.69451841099
# Update: 5300 Objective: 2.68982177612
# Update: 5310 Objective: 2.68515601223
# Update: 5320 Objective: 2.68052091639
# Update: 5330 Objective: 2.67591628703
# Update: 5340 Objective: 2.67134192389
# Update: 5350 Objective: 2.66679762803
# Update: 5360 Objective: 2.66228320182
# Update: 5370 Objective: 2.65779844893
# Update: 5380 Objective: 2.6533431743
# Update: 5390 Objective: 2.64891718419
# Update: 5400 Objective: 2.6445202861
# Update: 5410 Objective: 2.64015228882
# Update: 5420 Objective: 2.63581300237
# Update: 5430 Objective: 2.63150223805
# Update: 5440 Objective: 2.62721980837
# Update: 5450 Objective: 2.62296552709
# Update: 5460 Objective: 2.6187392092
# Update: 5470 Objective: 2.61454067088
# Update: 5480 Objective: 2.61036972955
# Update: 5490 Objective: 2.60622620381
# Update: 5500 Objective: 2.60210991346
# Update: 5510 Objective: 2.59802067948
# Update: 5520 Objective: 2.59395832402
# Update: 5530 Objective: 2.58992267042
# Update: 5540 Objective: 2.58591354316
# Update: 5550 Objective: 2.58193076789
# Update: 5560 Objective: 2.57797417139
# Update: 5570 Objective: 2.57404358159
# Update: 5580 Objective: 2.57013882755
# Update: 5590 Objective: 2.56625973946
# Update: 5600 Objective: 2.5624061486
# Update: 5610 Objective: 2.55857788739
# Update: 5620 Objective: 2.55477478933
# Update: 5630 Objective: 2.55099668903
# Update: 5640 Objective: 2.54724342217
# Update: 5650 Objective: 2.54351482553
# Update: 5660 Objective: 2.53981073695
# Update: 5670 Objective: 2.53613099534
# Update: 5680 Objective: 2.53247544066
# Update: 5690 Objective: 2.52884391393
# Update: 5700 Objective: 2.52523625723
# Update: 5710 Objective: 2.52165231364
# Update: 5720 Objective: 2.51809192731
# Update: 5730 Objective: 2.51455494339
# Update: 5740 Objective: 2.51104120806
# Update: 5750 Objective: 2.50755056851
# Update: 5760 Objective: 2.50408287292
# Update: 5770 Objective: 2.50063797049
# Update: 5780 Objective: 2.4972157114
# Update: 5790 Objective: 2.49381594681
# Update: 5800 Objective: 2.49043852886
# Update: 5810 Objective: 2.48708331068
# Update: 5820 Objective: 2.48375014634
# Update: 5830 Objective: 2.48043889088
# Update: 5840 Objective: 2.4771494003
# Update: 5850 Objective: 2.47388153154
# Update: 5860 Objective: 2.47063514247
# Update: 5870 Objective: 2.46741009191
# Update: 5880 Objective: 2.4642062396
# Update: 5890 Objective: 2.46102344621
# Update: 5900 Objective: 2.45786157331
# Update: 5910 Objective: 2.45472048339
# Update: 5920 Objective: 2.45160003986
# Update: 5930 Objective: 2.44850010699
# Update: 5940 Objective: 2.44542054998
# Update: 5950 Objective: 2.44236123488
# Update: 5960 Objective: 2.43932202867
# Update: 5970 Objective: 2.43630279914
# Update: 5980 Objective: 2.43330341501
# Update: 5990 Objective: 2.43032374583
# Update: 6000 Objective: 2.427363662
# Update: 6010 Objective: 2.4244230348
# Update: 6020 Objective: 2.42150173634
# Update: 6030 Objective: 2.41859963956
# Update: 6040 Objective: 2.41571661826
# Update: 6050 Objective: 2.41285254706
# Update: 6060 Objective: 2.41000730139
# Update: 6070 Objective: 2.40718075752
# Update: 6080 Objective: 2.40437279251
# Update: 6090 Objective: 2.40158328425
# Update: 6100 Objective: 2.39881211143
# Update: 6110 Objective: 2.39605915351
# Update: 6120 Objective: 2.39332429079
# Update: 6130 Objective: 2.39060740431
# Update: 6140 Objective: 2.38790837593
# Update: 6150 Objective: 2.38522708825
# Update: 6160 Objective: 2.38256342467
# Update: 6170 Objective: 2.37991726934
# Update: 6180 Objective: 2.37728850719
# Update: 6190 Objective: 2.37467702389
# Update: 6200 Objective: 2.37208270586
# Update: 6210 Objective: 2.36950544029
# Update: 6220 Objective: 2.36694511507
# Update: 6230 Objective: 2.36440161886
# Update: 6240 Objective: 2.36187484106
# Update: 6250 Objective: 2.35936467175
# Update: 6260 Objective: 2.35687100179
# Update: 6270 Objective: 2.35439372271
# Update: 6280 Objective: 2.35193272679
# Update: 6290 Objective: 2.34948790698
# Update: 6300 Objective: 2.34705915697
# Update: 6310 Objective: 2.34464637113
# Update: 6320 Objective: 2.34224944453
# Update: 6330 Objective: 2.33986827292
# Update: 6340 Objective: 2.33750275275
# Update: 6350 Objective: 2.33515278114
# Update: 6360 Objective: 2.33281825589
# Update: 6370 Objective: 2.33049907546
# Update: 6380 Objective: 2.32819513901
# Update: 6390 Objective: 2.32590634633
# Update: 6400 Objective: 2.32363259787
# Update: 6410 Objective: 2.32137379476
# Update: 6420 Objective: 2.31912983876
# Update: 6430 Objective: 2.31690063228
# Update: 6440 Objective: 2.31468607836
# Update: 6450 Objective: 2.31248608071
# Update: 6460 Objective: 2.31030054364
# Update: 6470 Objective: 2.3081293721
# Update: 6480 Objective: 2.30597247166
# Update: 6490 Objective: 2.30382974853
# Update: 6500 Objective: 2.30170110951
# Update: 6510 Objective: 2.29958646203
# Update: 6520 Objective: 2.29748571413
# Update: 6530 Objective: 2.29539877443
# Update: 6540 Objective: 2.29332555219
# Update: 6550 Objective: 2.29126595724
# Update: 6560 Objective: 2.2892199
# Update: 6570 Objective: 2.28718729149
# Update: 6580 Objective: 2.28516804331
# Update: 6590 Objective: 2.28316206764
# Update: 6600 Objective: 2.28116927725
# Update: 6610 Objective: 2.27918958547
# Update: 6620 Objective: 2.2772229062
# Update: 6630 Objective: 2.2752691539
# Update: 6640 Objective: 2.27332824362
# Update: 6650 Objective: 2.27140009094
# Update: 6660 Objective: 2.269484612
# Update: 6670 Objective: 2.2675817235
# Update: 6680 Objective: 2.26569134268
# Update: 6690 Objective: 2.26381338733
# Update: 6700 Objective: 2.26194777578
# Update: 6710 Objective: 2.26009442689
# Update: 6720 Objective: 2.25825326006
# Update: 6730 Objective: 2.25642419521
# Update: 6740 Objective: 2.25460715281
# Update: 6750 Objective: 2.25280205382
# Update: 6760 Objective: 2.25100881974
# Update: 6770 Objective: 2.24922737259
# Update: 6780 Objective: 2.24745763489
# Update: 6790 Objective: 2.24569952967
# Update: 6800 Objective: 2.24395298047
# Update: 6810 Objective: 2.24221791134
# Update: 6820 Objective: 2.24049424681
# Update: 6830 Objective: 2.23878191193
# Update: 6840 Objective: 2.23708083222
# Update: 6850 Objective: 2.2353909337
# Update: 6860 Objective: 2.23371214288
# Update: 6870 Objective: 2.23204438676
# Update: 6880 Objective: 2.23038759279
# Update: 6890 Objective: 2.22874168892
# Update: 6900 Objective: 2.22710660358
# Update: 6910 Objective: 2.22548226565
# Update: 6920 Objective: 2.22386860449
# Update: 6930 Objective: 2.22226554992
# Update: 6940 Objective: 2.22067303223
# Update: 6950 Objective: 2.21909098215
# Update: 6960 Objective: 2.21751933088
# Update: 6970 Objective: 2.21595801008
# Update: 6980 Objective: 2.21440695183
# Update: 6990 Objective: 2.21286608869
# Update: 7000 Objective: 2.21133535364
# Update: 7010 Objective: 2.2098146801
# Update: 7020 Objective: 2.20830400196
# Update: 7030 Objective: 2.20680325349
# Update: 7040 Objective: 2.20531236944
# Update: 7050 Objective: 2.20383128497
# Update: 7060 Objective: 2.20235993567
# Update: 7070 Objective: 2.20089825754
# Update: 7080 Objective: 2.19944618702
# Update: 7090 Objective: 2.19800366096
# Update: 7100 Objective: 2.19657061661
# Update: 7110 Objective: 2.19514699167
# Update: 7120 Objective: 2.19373272421
# Update: 7130 Objective: 2.19232775273
# Update: 7140 Objective: 2.19093201612
# Update: 7150 Objective: 2.18954545368
# Update: 7160 Objective: 2.18816800512
# Update: 7170 Objective: 2.18679961053
# Update: 7180 Objective: 2.18544021039
# Update: 7190 Objective: 2.18408974558
# Update: 7200 Objective: 2.18274815738
# Update: 7210 Objective: 2.18141538743
# Update: 7220 Objective: 2.18009137778
# Update: 7230 Objective: 2.17877607084
# Update: 7240 Objective: 2.17746940941
# Update: 7250 Objective: 2.17617133667
# Update: 7260 Objective: 2.17488179615
# Update: 7270 Objective: 2.17360073178
# Update: 7280 Objective: 2.17232808785
# Update: 7290 Objective: 2.171063809
# Update: 7300 Objective: 2.16980784025
# Update: 7310 Objective: 2.16856012699
# Update: 7320 Objective: 2.16732061494
# Update: 7330 Objective: 2.1660892502
# Update: 7340 Objective: 2.16486597922
# Update: 7350 Objective: 2.1636507488
# Update: 7360 Objective: 2.16244350608
# Update: 7370 Objective: 2.16124419857
# Update: 7380 Objective: 2.16005277411
# Update: 7390 Objective: 2.15886918087
# Update: 7400 Objective: 2.15769336739
# Update: 7410 Objective: 2.15652528254
# Update: 7420 Objective: 2.1553648755
# Update: 7430 Objective: 2.15421209581
# Update: 7440 Objective: 2.15306689335
# Update: 7450 Objective: 2.15192921829
# Update: 7460 Objective: 2.15079902118
# Update: 7470 Objective: 2.14967625284
# Update: 7480 Objective: 2.14856086446
# Update: 7490 Objective: 2.14745280753
# Update: 7500 Objective: 2.14635203385
# Update: 7510 Objective: 2.14525849556
# Update: 7520 Objective: 2.14417214509
# Update: 7530 Objective: 2.1430929352
# Update: 7540 Objective: 2.14202081895
# Update: 7550 Objective: 2.14095574973
# Update: 7560 Objective: 2.1398976812
# Update: 7570 Objective: 2.13884656735
# Update: 7580 Objective: 2.13780236247
# Update: 7590 Objective: 2.13676502115
# Update: 7600 Objective: 2.13573449828
# Update: 7610 Objective: 2.13471074902
# Update: 7620 Objective: 2.13369372887
# Update: 7630 Objective: 2.13268339359
# Update: 7640 Objective: 2.13167969925
# Update: 7650 Objective: 2.13068260218
# Update: 7660 Objective: 2.12969205903
# Update: 7670 Objective: 2.12870802672
# Update: 7680 Objective: 2.12773046245
# Update: 7690 Objective: 2.12675932371
# Update: 7700 Objective: 2.12579456827
# Update: 7710 Objective: 2.12483615415
# Update: 7720 Objective: 2.1238840397
# Update: 7730 Objective: 2.12293818349
# Update: 7740 Objective: 2.12199854439
# Update: 7750 Objective: 2.12106508153
# Update: 7760 Objective: 2.12013775433
# Update: 7770 Objective: 2.11921652245
# Update: 7780 Objective: 2.11830134582
# Update: 7790 Objective: 2.11739218464
# Update: 7800 Objective: 2.11648899938
# Update: 7810 Objective: 2.11559175076
# Update: 7820 Objective: 2.11470039975
# Update: 7830 Objective: 2.11381490759
# Update: 7840 Objective: 2.11293523576
# Update: 7850 Objective: 2.11206134602
# Update: 7860 Objective: 2.11119320035
# Update: 7870 Objective: 2.110330761
# Update: 7880 Objective: 2.10947399047
# Update: 7890 Objective: 2.10862285148
# Update: 7900 Objective: 2.10777730704
# Update: 7910 Objective: 2.10693732035
# Update: 7920 Objective: 2.10610285489
# Update: 7930 Objective: 2.10527387438
# Update: 7940 Objective: 2.10445034275
# Update: 7950 Objective: 2.10363222419
# Update: 7960 Objective: 2.10281948313
# Update: 7970 Objective: 2.10201208421
# Update: 7980 Objective: 2.10120999232
# Update: 7990 Objective: 2.10041317258
# Update: 8000 Objective: 2.09962159033
# Update: 8010 Objective: 2.09883521116
# Update: 8020 Objective: 2.09805400085
# Update: 8030 Objective: 2.09727792544
# Update: 8040 Objective: 2.09650695116
# Update: 8050 Objective: 2.09574104451
# Update: 8060 Objective: 2.09498017215
# Update: 8070 Objective: 2.09422430101
# Update: 8080 Objective: 2.0934733982
# Update: 8090 Objective: 2.09272743108
# Update: 8100 Objective: 2.0919863672
# Update: 8110 Objective: 2.09125017433
# Update: 8120 Objective: 2.09051882046
# Update: 8130 Objective: 2.08979227377
# Update: 8140 Objective: 2.08907050267
# Update: 8150 Objective: 2.08835347578
# Update: 8160 Objective: 2.0876411619
# Update: 8170 Objective: 2.08693353005
# Update: 8180 Objective: 2.08623054947
# Update: 8190 Objective: 2.08553218958
# Update: 8200 Objective: 2.08483842001
# Update: 8210 Objective: 2.08414921059
# Update: 8220 Objective: 2.08346453133
# Update: 8230 Objective: 2.08278435248
# Update: 8240 Objective: 2.08210864443
# Update: 8250 Objective: 2.08143737782
# Update: 8260 Objective: 2.08077052344
# Update: 8270 Objective: 2.08010805229
# Update: 8280 Objective: 2.07944993556
# Update: 8290 Objective: 2.07879614463
# Update: 8300 Objective: 2.07814665107
# Update: 8310 Objective: 2.07750142663
# Update: 8320 Objective: 2.07686044325
# Update: 8330 Objective: 2.07622367305
# Update: 8340 Objective: 2.07559108834
# Update: 8350 Objective: 2.07496266161
# Update: 8360 Objective: 2.07433836552
# Update: 8370 Objective: 2.07371817294
# Update: 8380 Objective: 2.07310205688
# Update: 8390 Objective: 2.07248999054
# Update: 8400 Objective: 2.07188194732
# Update: 8410 Objective: 2.07127790077
# Update: 8420 Objective: 2.07067782461
# Update: 8430 Objective: 2.07008169275
# Update: 8440 Objective: 2.06948947927
# Update: 8450 Objective: 2.0689011584
# Update: 8460 Objective: 2.06831670456
# Update: 8470 Objective: 2.06773609234
# Update: 8480 Objective: 2.06715929649
# Update: 8490 Objective: 2.06658629191
# Update: 8500 Objective: 2.06601705368
# Update: 8510 Objective: 2.06545155706
# Update: 8520 Objective: 2.06488977745
# Update: 8530 Objective: 2.06433169042
# Update: 8540 Objective: 2.06377727169
# Update: 8550 Objective: 2.06322649715
# Update: 8560 Objective: 2.06267934285
# Update: 8570 Objective: 2.062135785
# Update: 8580 Objective: 2.06159579995
# Update: 8590 Objective: 2.06105936423
# Update: 8600 Objective: 2.06052645449
# Update: 8610 Objective: 2.05999704757
# Update: 8620 Objective: 2.05947112044
# Update: 8630 Objective: 2.05894865022
# Update: 8640 Objective: 2.05842961421
# Update: 8650 Objective: 2.05791398981
# Update: 8660 Objective: 2.05740175462
# Update: 8670 Objective: 2.05689288634
# Update: 8680 Objective: 2.05638736286
# Update: 8690 Objective: 2.05588516218
# Update: 8700 Objective: 2.05538626246
# Update: 8710 Objective: 2.05489064201
# Update: 8720 Objective: 2.05439827927
# Update: 8730 Objective: 2.05390915284
# Update: 8740 Objective: 2.05342324143
# Update: 8750 Objective: 2.05294052391
# Update: 8760 Objective: 2.0524609793
# Update: 8770 Objective: 2.05198458673
# Update: 8780 Objective: 2.05151132549
# Update: 8790 Objective: 2.05104117499
# Update: 8800 Objective: 2.0505741148
# Update: 8810 Objective: 2.05011012458
# Update: 8820 Objective: 2.04964918418
# Update: 8830 Objective: 2.04919127354
# Update: 8840 Objective: 2.04873637274
# Update: 8850 Objective: 2.048284462
# Update: 8860 Objective: 2.04783552167
# Update: 8870 Objective: 2.04738953223
# Update: 8880 Objective: 2.04694647427
# Update: 8890 Objective: 2.04650632854
# Update: 8900 Objective: 2.04606907588
# Update: 8910 Objective: 2.04563469728
# Update: 8920 Objective: 2.04520317385
# Update: 8930 Objective: 2.04477448682
# Update: 8940 Objective: 2.04434861755
# Update: 8950 Objective: 2.04392554752
# Update: 8960 Objective: 2.04350525833
# Update: 8970 Objective: 2.0430877317
# Update: 8980 Objective: 2.04267294947
# Update: 8990 Objective: 2.04226089361
# Update: 9000 Objective: 2.04185154618
# Update: 9010 Objective: 2.0414448894
# Update: 9020 Objective: 2.04104090557
# Update: 9030 Objective: 2.04063957712
# Update: 9040 Objective: 2.04024088661
# Update: 9050 Objective: 2.03984481669
# Update: 9060 Objective: 2.03945135013
# Update: 9070 Objective: 2.03906046983
# Update: 9080 Objective: 2.03867215879
# Update: 9090 Objective: 2.03828640011
# Update: 9100 Objective: 2.03790317703
# Update: 9110 Objective: 2.03752247286
# Update: 9120 Objective: 2.03714427107
# Update: 9130 Objective: 2.0367685552
# Update: 9140 Objective: 2.0363953089
# Update: 9150 Objective: 2.03602451596
# Update: 9160 Objective: 2.03565616023
# Update: 9170 Objective: 2.03529022571
# Update: 9180 Objective: 2.03492669647
# Update: 9190 Objective: 2.03456555671
# Update: 9200 Objective: 2.03420679072
# Update: 9210 Objective: 2.0338503829
# Update: 9220 Objective: 2.03349631775
# Update: 9230 Objective: 2.03314457986
# Update: 9240 Objective: 2.03279515395
# Update: 9250 Objective: 2.03244802482
# Update: 9260 Objective: 2.03210317736
# Update: 9270 Objective: 2.03176059659
# Update: 9280 Objective: 2.0314202676
# Update: 9290 Objective: 2.03108217559
# Update: 9300 Objective: 2.03074630586
# Update: 9310 Objective: 2.0304126438
# Update: 9320 Objective: 2.0300811749
# Update: 9330 Objective: 2.02975188474
# Update: 9340 Objective: 2.02942475901
# Update: 9350 Objective: 2.02909978347
# Update: 9360 Objective: 2.028776944
# Update: 9370 Objective: 2.02845622655
# Update: 9380 Objective: 2.02813761718
# Update: 9390 Objective: 2.02782110202
# Update: 9400 Objective: 2.02750666732
# Update: 9410 Objective: 2.0271942994
# Update: 9420 Objective: 2.02688398467
# Update: 9430 Objective: 2.02657570964
# Update: 9440 Objective: 2.0262694609
# Update: 9450 Objective: 2.02596522514
# Update: 9460 Objective: 2.02566298911
# Update: 9470 Objective: 2.02536273968
# Update: 9480 Objective: 2.02506446379
# Update: 9490 Objective: 2.02476814847
# Update: 9500 Objective: 2.02447378083
# Update: 9510 Objective: 2.02418134806
# Update: 9520 Objective: 2.02389083746
# Update: 9530 Objective: 2.02360223638
# Update: 9540 Objective: 2.02331553227
# Update: 9550 Objective: 2.02303071267
# Update: 9560 Objective: 2.02274776519
# Update: 9570 Objective: 2.02246667752
# Update: 9580 Objective: 2.02218743744
# Update: 9590 Objective: 2.02191003281
# Update: 9600 Objective: 2.02163445156
# Update: 9610 Objective: 2.0213606817
# Update: 9620 Objective: 2.02108871133
# Update: 9630 Objective: 2.02081852862
# Update: 9640 Objective: 2.02055012182
# Update: 9650 Objective: 2.02028347926
# Update: 9660 Objective: 2.02001858934
# Update: 9670 Objective: 2.01975544054
# Update: 9680 Objective: 2.01949402141
# Update: 9690 Objective: 2.0192343206
# Update: 9700 Objective: 2.01897632679
# Update: 9710 Objective: 2.01872002878
# Update: 9720 Objective: 2.01846541542
# Update: 9730 Objective: 2.01821247563
# Update: 9740 Objective: 2.01796119841
# Update: 9750 Objective: 2.01771157284
# Update: 9760 Objective: 2.01746358806
# Update: 9770 Objective: 2.01721723327
# Update: 9780 Objective: 2.01697249778
# Update: 9790 Objective: 2.01672937094
# Update: 9800 Objective: 2.01648784216
# Update: 9810 Objective: 2.01624790096
# Update: 9820 Objective: 2.01600953689
# Update: 9830 Objective: 2.01577273958
# Update: 9840 Objective: 2.01553749874
# Update: 9850 Objective: 2.01530380414
# Update: 9860 Objective: 2.01507164562
# Update: 9870 Objective: 2.01484101307
# Update: 9880 Objective: 2.01461189647
# Update: 9890 Objective: 2.01438428585
# Update: 9900 Objective: 2.01415817132
# Update: 9910 Objective: 2.01393354304
# Update: 9920 Objective: 2.01371039123
# Update: 9930 Objective: 2.01348870621
# Update: 9940 Objective: 2.01326847832
# Update: 9950 Objective: 2.01304969799
# Update: 9960 Objective: 2.0128323557
# Update: 9970 Objective: 2.012616442
# Update: 9980 Objective: 2.0124019475
# Update: 9990 Objective: 2.01218886287
# Update: 10000 Objective: 2.01197717885
# Update: 10010 Objective: 2.01176688623
# Update: 10020 Objective: 2.01155797585
# Update: 10030 Objective: 2.01135043865
# Update: 10040 Objective: 2.01114426559
# Update: 10050 Objective: 2.0109394477
# Update: 10060 Objective: 2.01073597609
# Update: 10070 Objective: 2.01053384189
# Update: 10080 Objective: 2.01033303631
# Update: 10090 Objective: 2.01013355063
# Update: 10100 Objective: 2.00993537618
# Update: 10110 Objective: 2.00973850432
# Update: 10120 Objective: 2.0095429265
# Update: 10130 Objective: 2.00934863421
# Update: 10140 Objective: 2.00915561901
# Update: 10150 Objective: 2.00896387249
# Update: 10160 Objective: 2.00877338632
# Update: 10170 Objective: 2.00858415222
# Update: 10180 Objective: 2.00839616196
# Update: 10190 Objective: 2.00820940735
# Update: 10200 Objective: 2.00802388028
# Update: 10210 Objective: 2.00783957268
# Update: 10220 Objective: 2.00765647654
# Update: 10230 Objective: 2.00747458388
# Update: 10240 Objective: 2.0072938868
# Update: 10250 Objective: 2.00711437745
# Update: 10260 Objective: 2.00693604801
# Update: 10270 Objective: 2.00675889073
# Update: 10280 Objective: 2.00658289791
# Update: 10290 Objective: 2.00640806188
# Update: 10300 Objective: 2.00623437505
# Update: 10310 Objective: 2.00606182987
# Update: 10320 Objective: 2.00589041882
# Update: 10330 Objective: 2.00572013446
# Update: 10340 Objective: 2.00555096938
# Update: 10350 Objective: 2.00538291622
# Update: 10360 Objective: 2.00521596767
# Update: 10370 Objective: 2.00505011647
# Update: 10380 Objective: 2.00488535542
# Update: 10390 Objective: 2.00472167734
# Update: 10400 Objective: 2.00455907511
# Update: 10410 Objective: 2.00439754167
# Update: 10420 Objective: 2.00423706999
# Update: 10430 Objective: 2.00407765309
# Update: 10440 Objective: 2.00391928403
# Update: 10450 Objective: 2.00376195593
# Update: 10460 Objective: 2.00360566195
# Update: 10470 Objective: 2.0034503953
# Update: 10480 Objective: 2.0032961492
# Update: 10490 Objective: 2.00314291697
# Update: 10500 Objective: 2.00299069194
# Update: 10510 Objective: 2.00283946747
# Update: 10520 Objective: 2.00268923701
# Update: 10530 Objective: 2.00253999401
# Update: 10540 Objective: 2.00239173199
# Update: 10550 Objective: 2.00224444449
# Update: 10560 Objective: 2.00209812511
# Update: 10570 Objective: 2.00195276749
# Update: 10580 Objective: 2.0018083653
# Update: 10590 Objective: 2.00166491227
# Update: 10600 Objective: 2.00152240215
# Update: 10610 Objective: 2.00138082876
# Update: 10620 Objective: 2.00124018592
# Update: 10630 Objective: 2.00110046753
# Update: 10640 Objective: 2.00096166751
# Update: 10650 Objective: 2.00082377983
# Update: 10660 Objective: 2.00068679847
# Update: 10670 Objective: 2.0005507175
# Update: 10680 Objective: 2.00041553098
# Update: 10690 Objective: 2.00028123305
# Update: 10700 Objective: 2.00014781786
# Update: 10710 Objective: 2.0000152796
# Update: 10720 Objective: 1.99988361252
# Update: 10730 Objective: 1.99975281088
# Update: 10740 Objective: 1.99962286901
# Update: 10750 Objective: 1.99949378124
# Update: 10760 Objective: 1.99936554197
# Update: 10770 Objective: 1.99923814561
# Update: 10780 Objective: 1.99911158663
# Update: 10790 Objective: 1.99898585952
# Update: 10800 Objective: 1.99886095881
# Update: 10810 Objective: 1.99873687908
# Update: 10820 Objective: 1.99861361492
# Update: 10830 Objective: 1.99849116097
# Update: 10840 Objective: 1.99836951192
# Update: 10850 Objective: 1.99824866247
# Update: 10860 Objective: 1.99812860736
# Update: 10870 Objective: 1.99800934137
# Update: 10880 Objective: 1.99789085931
# Update: 10890 Objective: 1.99777315604
# Update: 10900 Objective: 1.99765622643
# Update: 10910 Objective: 1.9975400654
# Update: 10920 Objective: 1.9974246679
# Update: 10930 Objective: 1.9973100289
# Update: 10940 Objective: 1.99719614343
# Update: 10950 Objective: 1.99708300652
# Update: 10960 Objective: 1.99697061327
# Update: 10970 Objective: 1.99685895877
# Update: 10980 Objective: 1.99674803818
# Update: 10990 Objective: 1.99663784667
# Update: 11000 Objective: 1.99652837945
# Update: 11010 Objective: 1.99641963175
# Update: 11020 Objective: 1.99631159886
# Update: 11030 Objective: 1.99620427606
# Update: 11040 Objective: 1.9960976587
# Update: 11050 Objective: 1.99599174213
# Update: 11060 Objective: 1.99588652175
# Update: 11070 Objective: 1.99578199299
# Update: 11080 Objective: 1.99567815129
# Update: 11090 Objective: 1.99557499214
# Update: 11100 Objective: 1.99547251106
# Update: 11110 Objective: 1.99537070359
# Update: 11120 Objective: 1.9952695653
# Update: 11130 Objective: 1.99516909179
# m:  -0.013645990308 c: 30.1968529257

# %% [markdown]
# #### Question 3 Answer Here
#
# Write your answer to the question in this box.
#
# In coordinate descent, we choose to move one parameter at a time. Ideally, we design an algorithm that at each step moves the parameter to its minimum value. At each step we choose to move the individual parameter to its minimum.
# Partial derivatives of the objective function are calculated, therefore we are left with 2 equations that need to be rearranged and substituted into one another (m and c equations). This is time consuming.
#
# Each updated value of m and c is calculated from the partial derivatives respectively. Each iteration moves the parameters to their minimum value and calculates the objective function. Therefore in each iteration there is an updated value for m, c and the objective function. At the beginning the parameters are far away from their minimum, therefore the objective function correction that is required is high. As the parameters move closer to their minimum, the correction required decreases. Therefore many iterations are needed to move the objective function to a point where the correction required is less than 0.001 from its 10 iterations. It is assumed that if the correction is less than 0.001, then the objective function has reached an acceptable value; where any further corrections would not make any significant difference.
#
# Also, in each iteration the updated value of c depends on m and vice versa. Therefore each parameter depends on the previous value of the other parameter. So it can not go directly to the minimum, it must pass from each step. To do that it requires many iterations.
#
# We can overcome this by using multiple input solution with linear algebra, where each parameter is moved directly to its minimum.

# %% [markdown]
# ## Multiple Input Solution with Linear Algebra
#
# You've now seen how slow it can be to perform a coordinate ascent on a system. Another approach to solving the system (which is not always possible, particularly in *non-linear* systems) is to go direct to the minimum. To do this we need to introduce *linear algebra*. We will represent all our errors and functions in the form of linear algebra.
#
# As we mentioned above, linear algebra is just a shorthand for performing lots of multiplications and additions simultaneously. What does it have to do with our system then? Well the first thing to note is that the linear function we were trying to fit has the following form:
# $$
# f(x) = mx + c
# $$
# the classical form for a straight line. From a linear algebraic perspective we are looking for multiplications and additions. We are also looking to separate our parameters from our data. The data is the *givens* remember, in French the word is données literally translated means *givens* that's great, because we don't need to change the data, what we need to change are the parameters (or variables) of the model. In this function the data comes in through $x$, and the parameters are $m$ and $c$.
#
# What we'd like to create is a vector of parameters and a vector of data. Then we could represent the system with vectors that represent the data, and vectors that represent the parameters.
#
# We look to turn the multiplications and additions into a linear algebraic form, we have one multiplication ($m\times c$ and one addition ($mx + c$). But we can turn this into a inner product by writing it in the following way,
# $$
# f(x) = m \times x + c \times 1,
# $$
# in other words we've extracted the unit value, from the offset, $c$. We can think of this unit value like an extra item of data, because it is always given to us, and it is always set to 1 (unlike regular data, which is likely to vary!). We can therefore write each input data location, $\mathbf{x}$, as a vector
# $$
# \mathbf{x} = \begin{bmatrix} 1\\ x\end{bmatrix}.
# $$
#
# Now we choose to also turn our parameters into a vector. The parameter vector will be defined to contain
# $$
# \mathbf{w} = \begin{bmatrix} c \\ m\end{bmatrix}
# $$
# because if we now take the inner product between these to vectors we recover
# $$
# \mathbf{x}\cdot\mathbf{w} = 1 \times c + x \times m = mx + c
# $$
# In `numpy` we can define this vector as follows

# %%
# define the vector w
w = np.zeros(shape=(2, 1))
w[0] = m
w[1] = c

# %% [markdown]
# This gives us the equivalence between original operation and an operation in vector space. Whilst the notation here isn't a lot shorter, the beauty is that we will be able to add as many features as we like and still keep the seame representation. In general, we are now moving to a system where each of our predictions is given by an inner product. When we want to represent a linear product in linear algebra, we tend to do it with the transpose operation, so since we have $\mathbf{a}\cdot\mathbf{b} = \mathbf{a}^\top\mathbf{b}$ we can write
# $$
# f(\mathbf{x}_i) = \mathbf{x}_i^\top\mathbf{w}.
# $$
# Where we've assumed that each data point, $\mathbf{x}_i$, is now written by appending a 1 onto the original vector
# $$
# \mathbf{x}_i =
# \begin{bmatrix}
# 1 \\
# x_i
# \end{bmatrix}
# $$
#
# ## Design Matrix
#
# We can do this for the entire data set to form a [*design matrix*](http://en.wikipedia.org/wiki/Design_matrix) $\mathbf{X}$,
#
# $$\mathbf{X} = \begin{bmatrix}
# \mathbf{x}_1^\top \\\
# \mathbf{x}_2^\top \\\
# \vdots \\\
# \mathbf{x}_n^\top
# \end{bmatrix} = \begin{bmatrix}
# 1 & x_1 \\\
# 1 & x_2 \\\
# \vdots & \vdots \\\
# 1 & x_n
# \end{bmatrix},$$
#
# which in `numpy` can be done with the following commands:

# %%
X = np.hstack((np.ones_like(x), x))
print(X)
# Out:
# [[  1.00000000e+00   1.89600000e+03]
#  [  1.00000000e+00   1.90000000e+03]
#  [  1.00000000e+00   1.90400000e+03]
#  [  1.00000000e+00   1.90800000e+03]
#  [  1.00000000e+00   1.91200000e+03]
#  [  1.00000000e+00   1.92000000e+03]
#  [  1.00000000e+00   1.92400000e+03]
#  [  1.00000000e+00   1.92800000e+03]
#  [  1.00000000e+00   1.93200000e+03]
#  [  1.00000000e+00   1.93600000e+03]
#  [  1.00000000e+00   1.94800000e+03]
#  [  1.00000000e+00   1.95200000e+03]
#  [  1.00000000e+00   1.95600000e+03]
#  [  1.00000000e+00   1.96000000e+03]
#  [  1.00000000e+00   1.96400000e+03]
#  [  1.00000000e+00   1.96800000e+03]
#  [  1.00000000e+00   1.97200000e+03]
#  [  1.00000000e+00   1.97600000e+03]
#  [  1.00000000e+00   1.98000000e+03]
#  [  1.00000000e+00   1.98400000e+03]
#  [  1.00000000e+00   1.98800000e+03]
#  [  1.00000000e+00   1.99200000e+03]
#  [  1.00000000e+00   1.99600000e+03]
#  [  1.00000000e+00   2.00000000e+03]
#  [  1.00000000e+00   2.00400000e+03]
#  [  1.00000000e+00   2.00800000e+03]
#  [  1.00000000e+00   2.01200000e+03]]

# %% [markdown]
# ### Writing the Objective with Linear Algebra
#
# When we think of the objective function, we can think of it as the errors where the error is defined in a similar way to what it was in Legendre's day $y_i - f(\mathbf{x}_i)$, in statistics these errors are also sometimes called [*residuals*](http://en.wikipedia.org/wiki/Errors_and_residuals_in_statistics). So we can think as the objective and the prediction function as two separate parts, first we have,
# $$
# E(\mathbf{w}) = \sum_{i=1}^n (y_i - f(\mathbf{x}_i; \mathbf{w}))^2,
# $$
# where we've made the function $f(\cdot)$'s dependence on the parameters $\mathbf{w}$ explicit in this equation. Then we have the definition of the function itself,
# $$
# f(\mathbf{x}_i; \mathbf{w}) = \mathbf{x}_i^\top \mathbf{w}.
# $$
# Let's look again at these two equations and see if we can identify any inner products. The first equation is a sum of squares, which is promising. Any sum of squares can be represented by an inner product,
# $$
# a = \sum_{i=1}^{k} b^2_i = \mathbf{b}^\top\mathbf{b},
# $$
# so if we wish to represent $E(\mathbf{w})$ in this way, all we need to do is convert the sum operator to an inner product. We can get a vector from that sum operator by placing both $y_i$ and $f(\mathbf{x}_i; \mathbf{w})$ into vectors, which we do by defining
# $$
# \mathbf{y} = \begin{bmatrix}y_1\\y_2\\ \vdots \\ y_n\end{bmatrix}
# $$
# and defining
# $$
# \mathbf{f}(\mathbf{x}; \mathbf{w}) = \begin{bmatrix}f(\mathbf{x}_1; \mathbf{w})\\f(\mathbf{x}_2; \mathbf{w})\\ \vdots \\ f(\mathbf{x}_n; \mathbf{w})\end{bmatrix}.
# $$
# The second of these is actually a vector-valued function. This term may appear intimidating, but the idea is straightforward. A vector valued function is simply a vector whose elements are themselves defined as *functions*, i.e. it is a vector of functions, rather than a vector of scalars. The idea is so straightforward, that we are going to ignore it for the moment, and barely use it in the derivation. But it will reappear later when we introduce *basis functions*. So we will, for the moment, ignore the dependence of $\mathbf{f}$ on $\mathbf{w}$ and $\mathbf{X}$ and simply summarise it by a vector of numbers
# $$
# \mathbf{f} = \begin{bmatrix}f_1\\f_2\\ \vdots \\ f_n\end{bmatrix}.
# $$
# This allows us to write our objective in the folowing, linear algebraic form,
# $$
# E(\mathbf{w}) = (\mathbf{y} - \mathbf{f})^\top(\mathbf{y} - \mathbf{f})
# $$
# from the rules of inner products.
#
# But what of our matrix $\mathbf{X}$ of input data? At this point, we need to dust off [*matrix-vector multiplication*](http://en.wikipedia.org/wiki/Matrix_multiplication). Matrix multiplication is simply a convenient way of performing many inner products together, and it's exactly what we need to summarise the operation
# $$
# f_i = \mathbf{x}_i^\top\mathbf{w}.
# $$
# This operation tells us that each element of the vector $\mathbf{f}$ (our vector valued function) is given by an inner product between $\mathbf{x}_i$ and $\mathbf{w}$. In other words it is a series of inner products. Let's look at the definition of matrix multiplication, it takes the form
# $$
# \mathbf{c} = \mathbf{B}\mathbf{a}
# $$
# where $\mathbf{c}$ might be a $k$ dimensional vector (which we can intepret as a $k\times 1$ dimensional matrix), and $\mathbf{B}$ is a $k\times k$ dimensional matrix and $\mathbf{a}$ is a $k$ dimensional vector ($k\times 1$ dimensional matrix).
#
# The result of this multiplication is of the form
# $$
# \begin{bmatrix}c_1\\c_2 \\ \vdots \\ c_k\end{bmatrix} =
# \begin{bmatrix} b_{1,1} & b_{1, 2} & \dots & b_{1, k} \\
# b_{2, 1} & b_{2, 2} & \dots & b_{2, k} \\
# \vdots & \vdots & \ddots & \vdots \\
# b_{k, 1} & b_{k, 2} & \dots & b_{k, k} \end{bmatrix} \begin{bmatrix}a_1\\a_2 \\ \vdots\\ c_k\end{bmatrix} = \begin{bmatrix} b_{1, 1}a_1 + b_{1, 2}a_2 + \dots + b_{1, k}a_k\\
# b_{2, 1}a_1 + b_{2, 2}a_2 + \dots + b_{2, k}a_k \\
# \vdots\\
# b_{k, 1}a_1 + b_{k, 2}a_2 + \dots + b_{k, k}a_k\end{bmatrix}
# $$
# so we see that each element of the result, $\mathbf{c}$ is simply the inner product between each *row* of $\mathbf{B}$ and the vector $\mathbf{a}$. Because we have defined each element of $\mathbf{f}$ to be given by the inner product between each *row* of the design matrix and the vector $\mathbf{w}$ we now can write the full operation in one matrix multiplication,
# $$
# \mathbf{f} = \mathbf{X}\mathbf{w}.
# $$

# %%
f = np.dot(X, w) # np.dot does matrix multiplication in python

# %% [markdown]
# Combining this result with our objective function,
# $$
# E(\mathbf{w}) = (\mathbf{y} - \mathbf{f})^\top(\mathbf{y} - \mathbf{f})
# $$
# we find we have defined the *model* with two equations. One equation tells us the form of our predictive function and how it depends on its parameters, the other tells us the form of our objective function.

# %%
resid = (y-f)
E = np.dot(resid.T, resid) # matrix multiplication on a single vector is equivalent to a dot product.
print("Error function is:", E)
# Out:
# Error function is: [[  9.42427731e+10]]

# %% [markdown]
# ### Assignment Question 4
#
# The prediction for our movie recommender system had the form
# $$
# f_{i,j} = \mathbf{u}_i^\top \mathbf{v}_j
# $$
# and the objective function was then
# $$
# E = \sum_{i,j} s_{i,j}(y_{i,j} - f_{i, j})^2
# $$
# Try writing this down in matrix and vector form. How many of the terms can you do? For each variable and parameter carefully think about whether it should be represented as a matrix or vector. Do as many of the terms as you can. Use $\LaTeX$ to give your answers and give the *dimensions* of any matrices you create.
#
# *10 points*

# %% [markdown]
# #### Question 4 Answer
#
# Write your answer to the question in this box.
#
#
# $$
# E = \sum_{i,j} s_{i,j}(y_{i,j} - f_{i, j})^2
# $$
#
# $$
# E = \sum_{i=1}^n \sum_{j=1}^m s_{i,j}(y_{i,j} - f_{i, j})^2
# $$
#
#
# $\\ \\ \\ \\ \\ \\ \\ \\$
# $\mathbf{STEP \ 1 :} \\ SUMMATION\ OVER \sum_{j=1}^m $
#
# $$
# E = \sum_{i=1}^n s_{i,1}(y_{i,1} - f_{i, 1})^2 + s_{i,2}(y_{i,2} - f_{i, 2})^2 + ..... + s_{i,m}(y_{i,m} - f_{i, m})^2
# $$
#
# $\\ \\ \\$
#
# Create vectors for $\mathbf{y}$ and $\mathbf{f}$:
#
# $
# \mathbf{y_i} = \begin{bmatrix}y_1 & y_2 & \dots & y_m\end{bmatrix}
# $
# Which is an (1 x m) vector.
#
# $\\ \\ \\ $
#
# $
# \mathbf{f_i} = \begin{bmatrix}f_1 & f_2 & \dots & f_m\end{bmatrix}
# $
# Which is an (1 x m) vector.
#
# $\\ \\ \\ $
# Similarly create matrix for $\mathbf{S}$:
#
# $
# \mathbf{S_i} =\begin{bmatrix} S_{i,1} & 0 &\dots & 0 \\
# 0 & S_{i, 2} & \dots & 0 \\
# \vdots & \vdots & \ddots & 0 \\
# 0 & 0 & \dots & S_{i, m} \end{bmatrix}
# $
# Which is an (m x m)  matrix.
#
#
# $\\ \\ \\ \\$
#
# Then we define $\mathbf{y_i} - \mathbf{f_i}$:
#
# $(\mathbf{y_i} - \mathbf{f_i}) = \begin{bmatrix}y_1-f_1 & y_2-f_2 & \dots & y_m-f_m\end{bmatrix}$ which is (1 x m) vector.
#
# And therefore:
#
# $
# (\mathbf{y_i} - \mathbf{f_i})^\top = \begin{bmatrix}y_1-f_1\\y_2-f_2\\ \vdots \\ y_m - f_m\end{bmatrix}$ which is (m x 1) vector.
#
#
# $\\ \\ \\$
#
# In order to eliminate j, and have a scalar value for E we need to write to this form:
#
# $$E = \sum_{i=1}^n (\mathbf{y_i} - \mathbf{f_i}) \mathbf{S_i} (\mathbf{y_i} - \mathbf{f_i})^\top$$
#
# $$E =\sum_{i=1}^n \begin{bmatrix}y_1-f_1 & y_2-f_2 & \dots & y_m-f_m\end{bmatrix} \begin{bmatrix} S_{i,1} & 0 &\dots & 0 \\
# 0 & S_{i, 2} & \dots & 0 \\
# \vdots & \vdots & \ddots & 0 \\
# 0 & 0 & \dots & S_{i, m} \end{bmatrix} \begin{bmatrix}y_1-f_1\\y_2-f_2\\ \vdots \\ y_m - f_m\end{bmatrix}
# $$
#
# Because it is (1 x m)(m x m)(m x 1) and therefore we are left with a scalar (1 x 1).
#
#
# $\\ \\ \\ \\ \\ \\ \\ \\$
# $\mathbf{STEP \ 2 :} \\ SUMMATION\ OVER \sum_{i=1}^n $
#
#
# $\\ \\ \\$
#
# Create vectors of vectors for $\mathbf{y}$ and $\mathbf{f}$:
#
# $
# \mathbf{y} = \begin{bmatrix}\mathbf{y_1} & \mathbf{y_2} & \dots & \mathbf{y_n}\end{bmatrix}
# $
# Which is an (1 x n) vector of vectors.
#
# $\\ \\ \\ $
#
# $
# \mathbf{f} = \begin{bmatrix}\mathbf{f_1} & \mathbf{f_2} & \dots & \mathbf{f_2}\end{bmatrix}
# $
# Which is an (1 x n) vector of vectors.
#
# $\\ \\ \\ $
# Similarly for $\mathbf{S}$:
#
# $
# \mathbf{S} =\begin{bmatrix}\mathbf{S_1} & 0 &\dots & 0 \\
# 0 & \mathbf{S_2} & \dots & 0 \\
# \vdots & \vdots & \ddots & 0 \\
# 0 & 0 & \dots & \mathbf{S_n} \end{bmatrix}
# $
# Which is (n x n).
#
#
# $\\ \\ \\ \\$
#
# Then we define $\mathbf{y} - \mathbf{f}$:
#
# $(\mathbf{y} - \mathbf{f}) = \begin{bmatrix}\mathbf{y_1}-\mathbf{f_1} & \mathbf{y_2}-\mathbf{f_2} & \dots & \mathbf{y_n}-\mathbf{f_n}\end{bmatrix}$ which is (1 x n) vector of vectors.
#
# And therefore:
#
# $
# (\mathbf{y} - \mathbf{f})^\top = \begin{bmatrix}\mathbf{y_1}-\mathbf{f_1}\\\mathbf{y_2}-\mathbf{f_2}\\ \vdots \\ \mathbf{y_n} - \mathbf{f_n}\end{bmatrix}$ which is (n x 1) vector of vectors.
#
#
# $\\ \\ \\$
#
# In order to eliminate i, and have a scalar value for E we need to write to this form:
#
# $$E =(\mathbf{y} - \mathbf{f}) \mathbf{S} (\mathbf{y} - \mathbf{f})^\top$$
#
# $$E =\begin{bmatrix}\mathbf{y_1}-\mathbf{f_1} & \mathbf{y_2}-\mathbf{f_2} & \dots & \mathbf{y_n}-\mathbf{f_n}\end{bmatrix} \begin{bmatrix} \mathbf{S_1} & 0 &\dots & 0 \\
# 0 & \mathbf{S_2} & \dots & 0 \\
# \vdots & \vdots & \ddots & 0 \\
# 0 & 0 & \dots & \mathbf{S_n} \end{bmatrix} \begin{bmatrix}\mathbf{y_1}-\mathbf{f_1}\\\mathbf{y_2}-\mathbf{f_2}\\ \vdots \\ \mathbf{y_n} - \mathbf{f_n}\end{bmatrix}
# $$
#
# Because it is (1 x n)(n x n)(n x 1) and therefore we are left with a scalar (1 x 1).

# %% [markdown]
# ## Objective Optimisation
#
# Our *model* has now been defined with two equations, the prediction function and the objective function. Next we will use multivariate calculus to define an *algorithm* to fit the model. The separation between model and algorithm is important and is often overlooked. Our model contains a function that shows how it will be used for prediction, and a function that describes the objective function we need to optimise to obtain a good set of parameters.
#
# The linear regression model we have described is still the same as the one we fitted above with a coordinate ascent algorithm. We have only played with the notation to obtain the same model in a matrix and vector notation. However, we will now fit this model with a different algorithm, one that is much faster. It is such a widely used algorithm that from the end user's perspective it doesn't even look like an algorithm, it just appears to be a single operation (or function). However, underneath the computer calls an algorithm to find the solution. Further, the algorithm we obtain is very widely used, and because of this it turns out to be highly optimised.
#
# Once again we are going to try and find the stationary points of our objective by finding the *stationary points*. However, the stationary points of a multivariate function, are a little bit more complext to find. Once again we need to find the point at which the derivative is zero, but now we need to use  *multivariate calculus* to find it. This involves learning a few additional rules of differentiation (that allow you to do the derivatives of a function with respect to  vector), but in the end it makes things quite a bit easier. We define vectorial derivatives as follows,
# $$
# \frac{\text{d}E(\mathbf{w})}{\text{d}\mathbf{w}} = \begin{bmatrix}\frac{\text{d}E(\mathbf{w})}{\text{d}w_1}\\\frac{\text{d}E(\mathbf{w})}{\text{d}w_2}\end{bmatrix}.
# $$
# where $\frac{\text{d}E(\mathbf{w})}{\text{d}w_1}$ is the [partial derivative](http://en.wikipedia.org/wiki/Partial_derivative) of the error function with respect to $w_1$.
#
# Differentiation through multiplications and additions is relatively straightforward, and since linear algebra is just multiplication and addition, then its rules of diffentiation are quite straightforward too, but slightly more complex than regular derivatives.
#
# ### Matrix Differentiation
#
# We will need two rules of differentiation. The first is diffentiation of an inner product. By remebering that the inner product is made up of multiplication and addition, we can hope that its derivative is quite straightforward, and so it proves to be. We can start by thinking about the definition of the inner product,
# $$
# \mathbf{a}^\top\mathbf{z} = \sum_{i} a_i z_i,
# $$
# which if we were to take the derivative with respect to $z_k$ would simply return the gradient of the one term in the sum for which the derivative was non zero, that of $a_k$, so we know that
# $$
# \frac{\text{d}}{\text{d}z_k} \mathbf{a}^\top \mathbf{z} = a_k
# $$
# and by our definition of multivariate derivatives we can simply stack all the partial derivatives of this form in a vector to obtain the result that
# $$
# \frac{\text{d}}{\text{d}\mathbf{z}} \mathbf{a}^\top \mathbf{z} = \mathbf{a}.
# $$
# The second rule that's required is differentiation of a 'matrix quadratic'. A scalar quadratic in $z$ with coefficient $c$ has the form $cz^2$. If $\mathbf{z}$ is a $k\times 1$ vector and $\mathbf{C}$ is a $k \times k$ *matrix* of coefficients then the matrix quadratic form is written as $\mathbf{z}^\top \mathbf{C}\mathbf{z}$, which is itself a *scalar* quantity, but it is a function of a *vector*.
#
# #### Matching Dimensions in Matrix Multiplications
#
# There's a trick for telling that it's a scalar result. When you are doing maths with matrices, it's always worth pausing to perform a quick sanity check on the dimensions. Matrix multplication only works when the dimensions match. To be precise, the 'inner' dimension of the matrix must match. What is the inner dimension. If we multiply two matrices $\mathbf{A}$ and $\mathbf{B}$, the first of which has $k$ rows and $\ell$ columns and the second of which has $p$ rows and $q$ columns, then we can check whether the multiplication works by writing the dimensionalities next to each other,
# $$
# \mathbf{A} \mathbf{B} \rightarrow (k \times \underbrace{\ell)(p}_\text{inner dimensions} \times q) \rightarrow (k\times q).
# $$
# The inner dimensions are the two inside dimensions, $\ell$ and $p$. The multiplication will only work if $\ell=p$. The result of the multiplication will then be a $k\times q$ matrix: this dimensionality comes from the 'outer dimensions'. Note that matrix multiplication is not [*commutative*](http://en.wikipedia.org/wiki/Commutative_property). And if you change the order of the multiplication,
# $$
# \mathbf{B} \mathbf{A} \rightarrow (\ell \times \underbrace{k)(q}_\text{inner dimensions} \times p) \rightarrow (\ell \times p).
# $$
# firstly it may no longer even work, because now the condition is that $k=q$, and secondly the result could be of a different dimensionality. An exception is if the matrices are square matrices (e.g. same number of rows as columns) and they are both *symmetric*. A symmetric matrix is one for which $\mathbf{A}=\mathbf{A}^\top$, or equivalently, $a_{i,j} = a_{j,i}$ for all $i$ and $j$.
#
# You will need to get used to working with matrices and vectors applying and developing new machine learning techniques. You should have come across them before, but you may not have used them as extensively as we will now do in this course. You should get used to using this trick to check your work and ensure you know what the dimension of an output matrix should be. For our matrix quadratic form, it turns out that we can see it as a special type of inner product.
# $$
# \mathbf{z}^\top\mathbf{C}\mathbf{z} \rightarrow (1\times \underbrace{k) (k}_\text{inner dimensions}\times k) (k\times 1) \rightarrow \mathbf{b}^\top\mathbf{z}
# $$
# where $\mathbf{b} = \mathbf{C}\mathbf{z}$ so therefore the result is a scalar,
# $$
# \mathbf{b}^\top\mathbf{z} \rightarrow (1\times \underbrace{k) (k}_\text{inner dimensions}\times 1) \rightarrow (1\times 1)
# $$
# where a $(1\times 1)$ matrix is recognised as a scalar.
#
# This implies that we should be able to differentiate this form, and indeed the rule for its differentiation is slightly more complex than the inner product, but still quite simple,
# $$
# \frac{\text{d}}{\text{d}\mathbf{z}} \mathbf{z}^\top\mathbf{C}\mathbf{z}= \mathbf{C}\mathbf{z} + \mathbf{C}^\top \mathbf{z}.
# $$
# Note that in the special case where $\mathbf{C}$ is symmetric then we have $\mathbf{C} = \mathbf{C}^\top$ and the derivative simplifies to
# $$
# \frac{\text{d}}{\text{d}\mathbf{z}} \mathbf{z}^\top\mathbf{C}\mathbf{z}= 2\mathbf{C}\mathbf{z}.
# $$
# ### Differentiating the Objective
#
# First, we need to compute the full objective by substituting our prediction function into the objective function to obtain the objective in terms of $\mathbf{w}$. Doing this we obtain
# $$
# E(\mathbf{w})= (\mathbf{y} - \mathbf{X}\mathbf{w})^\top (\mathbf{y} - \mathbf{X}\mathbf{w}).
# $$
# We now need to differentiate this *quadratic form* to find the minimum. We differentiate with respect to the *vector* $\mathbf{w}$. But before we do that, we'll expand the brackets in the quadratic form to obtain a series of scalar terms. The rules for bracket expansion across the vectors are similar to those for the scalar system giving,
# $$
# (\mathbf{a} - \mathbf{b})^\top (\mathbf{c} - \mathbf{d}) = \mathbf{a}^\top \mathbf{c} - \mathbf{a}^\top \mathbf{d} - \mathbf{b}^\top \mathbf{c} + \mathbf{b}^\top \mathbf{d}
# $$
# which substituting for $\mathbf{a} = \mathbf{c} = \mathbf{y}$ and $\mathbf{b}=\mathbf{d} = \mathbf{X}\mathbf{w}$ gives
# $$
# E(\mathbf{w})= \mathbf{y}^\top\mathbf{y} - 2\mathbf{y}^\top\mathbf{X}\mathbf{w} + \mathbf{w}^\top\mathbf{X}^\top\mathbf{X}\mathbf{w}
# $$
# where we used the fact that $\mathbf{y}^\top\mathbf{X}\mathbf{w}= \mathbf{w}^\top\mathbf{X}^\top\mathbf{y}$. Now we can use our rules of differentiation to compute the derivative of this form, which is,
# $$
# \frac{\text{d}}{\text{d}\mathbf{w}}E(\mathbf{w})=- 2\mathbf{X}^\top \mathbf{y} + 2\mathbf{X}^\top\mathbf{X}\mathbf{w},
# $$
# where we have exploited the fact that $\mathbf{X}^\top\mathbf{X}$ is symmetric to obtain this result.

# %% [markdown]
# ### Assignment Question 5
#
# Use the equivalence between our vector and our matrix formulations of linear regression, alongside our definition of vector derivates, to match the gradients we've computed directly for $\frac{\text{d}E(c, m)}{\text{d}c}$ and $\frac{\text{d}E(c, m)}{\text{d}m}$ to those for $\frac{\text{d}E(\mathbf{w})}{\text{d}\mathbf{w}}$.
#
# *10 marks*

# %% [markdown]
# #### Question 5 Answer
#
# Write your answer to the question in this box.
#
# We need to show that:
#
# $$\displaystyle \begin{bmatrix} \frac{\partial}{\partial c} \\ \frac{\partial}{\partial m} \end{bmatrix} E(m,c) = \frac{\partial}{\partial\mathbf{w}} E(\mathbf{w})$$
#
#
#
# We can also write $\frac{\partial}{\partial\mathbf{w}} E(\mathbf{w})$ as:
#
# $$\frac{\partial}{\partial\mathbf{w}} E(\mathbf{w}) = \displaystyle \begin{bmatrix} \frac{\partial}{\partial w_0} \\ \frac{\partial}{\partial w1} \end{bmatrix}$$
#
# ie. $w_o = c$ and $w_1 = m$
#
# $\\ \\ \\$
#
# The full objective by substituting our prediction function into the objective function to obtain the objective in terms of $\mathbf{w}$ is:
# $$
# E(\mathbf{w})= (\mathbf{y} - \mathbf{X}\mathbf{w})^\top (\mathbf{y} - \mathbf{X}\mathbf{w}).
# $$
#
# $\\ \\ \\$
#
# Firstly, we need the multiplied out expression:
#
# $$
# E(\mathbf{w})= \mathbf{y}^\top\mathbf{y} - 2\mathbf{y}^\top\mathbf{X}\mathbf{w} + \mathbf{w}^\top\mathbf{X}^\top\mathbf{X}\mathbf{w}
# $$
# where we used the fact that $\mathbf{y}^\top\mathbf{X}\mathbf{w}= \mathbf{w}^\top\mathbf{X}^\top\mathbf{y}$.
#
# $\\ \\ \\ \\ \\$
#
#
# The first term doesn't include either $w_0$ or $w_1$ so we can ignore it. Therefore when multiplied out the first term is:
#
# $$w_0^2(\sum_{i=1}^n X_{i0}^2) + 2w_0w_1(\sum_{i=1}^n X_{i0}X_{n1}) + w_1^2(\sum_{i=1}^n X_{i1}^2)$$
#
# Where $X_{i0}$ is the first element of the nth row of $\mathbf{X}$ and $X_{i1}$ is the second. Similarly, the second term is:
#
# $$2w_0(\sum_{i=1}^n X_{i0}y_i) + 2w_1(\sum_{i=1}^n X_{i1}y_i)$$
#
# Combining these and noting that $X_{i0} = 1$ and that $X_{i1} = x_i$ :
#
# $$w_0^2 + 2w_0w_1(\sum_{i=1}^n x_i) + w_1^2(\sum_{i=1}^n x_{i1}^2) - 2w_0(\sum_{i=1}^n y_1) - 2w_1(\sum_{i=1}^n x_iy_i)$$
#
#
#
#
# Differentiating with respect to $w_0$ and $w_1$ respectivly:
#
# $$\frac{\partial}{\partial w_o} = 2w_0 + 2w_1\mathbf{x} - 2\mathbf{y}$$
#
# $$\frac{\partial}{\partial w_1} = 2w_0\mathbf{x} + 2w_1\mathbf{x^2} - 2\mathbf{xy}$$
#
# $\\ \\ \\ \\ \\$
#
# Since $w_o = c$ and $w_1 = m$, these equations can be writen as:
#
# $$\frac{\partial}{\partial c} = 2c + 2c\mathbf{x} - 2\mathbf{y}$$
#
# $$\frac{\partial}{\partial m} = 2c\mathbf{x} + 2m\mathbf{x^2} - 2\mathbf{xy}$$
#
#
#
# $\\ \\ \\ $
#
# Which are equal to the gradients that we computed directly:
#
# $$
# \frac{\text{d}E(m,c)}{\text{d}c} = -\sum_{i=1}^n 2(y_i-mx_i-c).
# $$
#
# $$
# \frac{\text{d}E(m,c)}{\text{d}m} = -\sum_{i=1}^n 2x_i(y_i-mx_i-c).
# $$
#
#
# These two partial derivatives make up the complete derivative (with respect to w) which is:
#
# $$
# \frac{\text{d}}{\text{d}\mathbf{w}}E(\mathbf{w})=- 2\mathbf{X}^\top \mathbf{y} + 2\mathbf{X}^\top\mathbf{X}\mathbf{w},
# $$

# %% [markdown]
# ## Update Equation for Global Optimum
#
# Once again, we need to find the minimum of our objective function. Using our likelihood for multiple input regression we can now minimize for our parameter vector $\mathbf{w}$. Firstly, just as in the single input case, we seek stationary points by find parameter vectors that solve for when the gradients are zero,
# $$
# \mathbf{0}=- 2\mathbf{X}^\top \mathbf{y} + 2\mathbf{X}^\top\mathbf{X}\mathbf{w},
# $$
# where $\mathbf{0}$ is a *vector* of zeros. Rearranging this equation we find the solution to be
# $$
# \mathbf{w} = \left[\mathbf{X}^\top \mathbf{X}\right]^{-1} \mathbf{X}^\top \mathbf{y}
# $$
# where $\mathbf{A}^{-1}$ denotes [*matrix inverse*](http://en.wikipedia.org/wiki/Invertible_matrix).
#
# ### Solving the Multivariate System
#
# The solution for $\mathbf{w}$ is given in terms of a matrix inverse, but computation of a matrix inverse requires, in itself, an algorithm to resolve it. You'll know this if you had to invert, by hand, a 3\times 3 matrix in high school. From a numerical stability perspective, it is also best not to compute the matrix inverse directly, but rather to ask the computer to *solve* the  system of linear equations given by
# $$\mathbf{X}^\top\mathbf{X} \mathbf{w} = \mathbf{X}^\top\mathbf{y}$$
# for $\mathbf{w}$. This can be done in `numpy` using the command

# %%
np.linalg.solve?

# %% [markdown]
# so we can obtain the solution using

# %%
w = np.linalg.solve(np.dot(X.T, X), np.dot(X.T, y))
print(w)
# Out:
# [[  2.88952457e+01]
#  [ -1.29806477e-02]]

# %% [markdown]
# We can map it back to the liner regression and plot the fit as follows

# %%
m = w[1]; c=w[0]
f_test = m*x_test + c
print(m)
print(c)
plt.plot(x_test, f_test, 'b-')
plt.plot(x, y, 'rx')
# Out:
# [-0.01298065]
# [ 28.89524574]

# %% [markdown]
# ## Multivariate Linear Regression
#
# A major advantage of the new system is that we can build a linear regression on a multivariate system. The matrix calculus didn't specify what the length of the vector $\mathbf{x}$ should be, or equivalently the size of the design matrix.
#
# ### Movie Body Count Data
#
# Let's load back in the movie body count data.

# %%
data = pods.datasets.movie_body_count()
movies = data['Y']

# %% [markdown]
# Let's remind ourselves of the features we've been provided with.

# %%
print(', '.join(movies.columns))
# Out:
# Film, Year, Body_Count, MPAA_Rating, Genre, Director, Actors, Length_Minutes, IMDB_Rating

# %% [markdown]
# Now we will build a design matrix based on the numeric features: year, Body_Count, Length_Minutes in an effort to predict the rating. We build the design matrix as follows:
#
# ## Relation to Single Input System
#
# Bias as an additional feature.

# %%
select_features = ['Year', 'Body_Count', 'Length_Minutes']
X = movies[select_features]
X['Eins'] = 1 # add a column for the offset
y = movies[['IMDB_Rating']]
# Out:
# //anaconda/lib/python3.5/site-packages/ipykernel/__main__.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()

# %% [markdown]
# Now let's perform a linear regression. But this time, we will create a pandas data frame for the result so we can store it in a form that we can visualise easily.

# %%
import pandas as pd
w = pd.DataFrame(data=np.linalg.solve(np.dot(X.T, X), np.dot(X.T, y)),  # solve linear regression here
                 index = X.columns,  # columns of X become rows of w
                 columns=['regression_coefficient']) # the column of X is the value of regression coefficient

# %% [markdown]
# We can check the residuals to see how good our estimates are

# %%
(y - np.dot(X, w)).hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x109983588>]], dtype=object)

# %% [markdown]
# Which shows our model *hasn't* yet done a great job of representation, because the spread of values is large. We can check what the rating is dominated by in terms of regression coefficients.

# %%
w
# Out:
#                 regression_coefficient
# Year                         -0.016280
# Body_Count                   -0.000995
# Length_Minutes                0.025386
# Eins                         36.508363

# %% [markdown]
# Although we have to be a little careful about interpretation because our input values live on different scales, however it looks like we are dominated by the bias, with a small negative effect for later films (but bear in mind the years are large, so this effect is probably larger than it looks) and a positive effect for length. So it looks like long earlier films generally do better, but the residuals are so high that we probably haven't modelled the system very well.

# %%
from IPython.display import YouTubeVideo
YouTubeVideo('ui-uNlFHoms')

# %%
from IPython.display import YouTubeVideo
YouTubeVideo('78YNphT90-k')

# %% [markdown]
# ## Solution with QR Decomposition
#
# Performing a solve instead of a matrix inverse is the more numerically stable approach, but we can do even better. A [QR-decomposition](http://en.wikipedia.org/wiki/QR_decomposition) of a matrix factorises it into a matrix which is an orthogonal matrix $\mathbf{Q}$, so that $\mathbf{Q}^\top \mathbf{Q} = \mathbf{I}$. And a matrix which is upper triangular, $\mathbf{R}$.
# $$
# \mathbf{X}^\top \mathbf{X} \boldsymbol{\beta} = \mathbf{X}^\top \mathbf{y}
# $$
# $$
# (\mathbf{Q}\mathbf{R})^\top (\mathbf{Q}\mathbf{R})\boldsymbol{\beta} = (\mathbf{Q}\mathbf{R})^\top \mathbf{y}
# $$
# $$
# \mathbf{R}^\top (\mathbf{Q}^\top \mathbf{Q}) \mathbf{R} \boldsymbol{\beta} = \mathbf{R}^\top \mathbf{Q}^\top \mathbf{y}
# $$
# $$
# \mathbf{R}^\top \mathbf{R} \boldsymbol{\beta} = \mathbf{R}^\top \mathbf{Q}^\top \mathbf{y}
# $$
# $$
# \mathbf{R} \boldsymbol{\beta} = \mathbf{Q}^\top \mathbf{y}
# $$
# This is a more numerically stable solution because it removes the need to compute $\mathbf{X}^\top\mathbf{X}$ as an intermediate. Computing $\mathbf{X}^\top\mathbf{X}$ is a bad idea because it involves squaring all the elements of $\mathbf{X}$ and thereby potentially reducing the numerical precision with which we can represent the solution. Operating on $\mathbf{X}$ directly preserves the numerical precision of the model.
#
# This can be more particularly seen when we begin to work with *basis functions* in the next session. Some systems that can be resolved with the QR decomposition can not be resolved by using solve directly.

# %%
import scipy as sp
Q, R = np.linalg.qr(X)
w = sp.linalg.solve_triangular(R, np.dot(Q.T, y)) 
w = pd.DataFrame(w, index=X.columns)
w
